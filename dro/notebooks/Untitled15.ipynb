# %%
import visual_behavior.database as db
import visual_behavior.plotting as vbp
from visual_behavior.utilities import EyeTrackingData
from allensdk.brain_observatory.behavior.behavior_project_cache import BehaviorProjectCache as bpc
from multiprocessing import Pool


from visual_behavior.translator.allensdk_sessions import sdk_utils


from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /home/dougo/.local/lib/python3.7/site-packages/xarray/core/merge.py:17: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/behavior_ophys_api/behavior_ophys_nwb_api.py:9: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
# <style>.container { width:100% !important; }</style>

# %%
manifest_path = "/home/dougo/manifest.json"
cache = bpc.from_lims(manifest=manifest_path)

# %%
oeid = 936494970
osid = sdk_utils.get_osid_from_oeid(oeid,cache)

# %%
eye_data = EyeTrackingData(osid)

# %%
dir(eye_data)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_ellipse',
#  'cr_color',
#  'ellipse_fits',
#  'eye_color',
#  'filepaths',
#  'filter_blinks',
#  'filter_outliers',
#  'foraging_id',
#  'get_annotated_frame',
#  'get_eye_data_from_file',
#  'get_matching_sync_line',
#  'ophys_experiment_id',
#  'ophys_session_id',
#  'pupil_color',
#  'sync_data',
#  'sync_timestamps']

# %%
eye_data.ellipse_fits['pupil'].iloc[1000:1010]
# Out:
#         center_x    center_y     height       phi      width         area  \
# 1000  339.732759  230.518579  34.502814  0.470115  39.533141  4909.898510
# 1001  338.924015  233.176245  34.576404  0.277948  39.703893  4952.403954
# 1002  337.502486  235.067322  34.485627  0.274934  39.517550  4906.026523
# 1003  339.843984  252.611272  32.953469 -0.123077  38.286381  4605.094099
# 1004  320.118083  262.904844  34.529345 -0.047023  38.356236  4621.913655
# 1005  319.748773  256.596288  31.254177  0.355990  36.309381  4141.785076
# 1006  326.132982  256.762756  29.349989  0.246259  37.452898  4406.773445
# 1007  321.294875  249.853658  30.650049  0.174324  37.362222  4385.461180
# 1008  324.264072  252.185895  33.870158  0.074987  38.371523  4625.598582
# 1009  325.621861  254.458053  33.506604  0.357437  38.071494  4553.545836
#
#           time  frame  likely_outlier  likely_blinks  \
# 1000  33.63624   1000           False          False
# ...

# %%
minimum_columns = ['time','frame','center_x','center_y','height','width','phi']

# %%
eye_data.ellipse_fits['pupil'] = eye_data.ellipse_fits['pupil'].rename(columns = {'normalized_blink_corrected_area':'normalized_area'})

# %%
eye_data.ellipse_fits['pupil']
# Out:
#         center_x  center_y  height  phi  width  area        time   frame  \
# 0            NaN       NaN     NaN  NaN    NaN   NaN     0.33152       0
# 1            NaN       NaN     NaN  NaN    NaN   NaN     0.34131       1
# 2            NaN       NaN     NaN  NaN    NaN   NaN     0.36786       2
# 3            NaN       NaN     NaN  NaN    NaN   NaN     0.40106       3
# 4            NaN       NaN     NaN  NaN    NaN   NaN     0.43443       4
# ...          ...       ...     ...  ...    ...   ...         ...     ...
# 136029       NaN       NaN     NaN  NaN    NaN   NaN  4534.53620  136029
# 136030       NaN       NaN     NaN  NaN    NaN   NaN  4534.57195  136030
# 136031       NaN       NaN     NaN  NaN    NaN   NaN  4534.60278  136031
# 136032       NaN       NaN     NaN  NaN    NaN   NaN  4534.63608  136032
# 136033       NaN       NaN     NaN  NaN    NaN   NaN  4534.67113  136033
#
#         likely_outlier  likely_blinks  blink_corrected_center_x  \
# ...

# %%
eye_data.ellipse_fits['pupil'].iloc[1000:1010][minimum_columns]
# Out:
#           time  frame    center_x    center_y     height      width       phi
# 1000  33.63624   1000  339.732759  230.518579  34.502814  39.533141  0.470115
# 1001  33.66730   1001  338.924015  233.176245  34.576404  39.703893  0.277948
# 1002  33.70073   1002  337.502486  235.067322  34.485627  39.517550  0.274934
# 1003  33.73399   1003  339.843984  252.611272  32.953469  38.286381 -0.123077
# 1004  33.76739   1004  320.118083  262.904844  34.529345  38.356236 -0.047023
# 1005  33.80065   1005  319.748773  256.596288  31.254177  36.309381  0.355990
# 1006  33.83423   1006  326.132982  256.762756  29.349989  37.452898  0.246259
# 1007  33.86727   1007  321.294875  249.853658  30.650049  37.362222  0.174324
# 1008  33.90074   1008  324.264072  252.185895  33.870158  38.371523  0.074987
# 1009  33.93415   1009  325.621861  254.458053  33.506604  38.071494  0.357437

# %%
eye_data.ellipse_fits['eye'].iloc[1000:1010][minimum_columns]
# Out:
#           time  frame    center_x    center_y      height       width  \
# 1000  33.63624   1000  330.002835  248.411670  124.949502  148.610527
# 1001  33.66730   1001  328.803618  250.204317  124.177995  148.982440
# 1002  33.70073   1002  326.757131  251.805200  122.359492  149.240452
# 1003  33.73399   1003  325.857526  255.680138  113.014242  141.929362
# 1004  33.76739   1004  326.038930  260.637072   75.402978  119.686605
# 1005  33.80065   1005  341.386178  260.525974   47.662817  105.671484
# 1006  33.83423   1006  334.645241  259.116761   39.883671   92.795543
# 1007  33.86727   1007  332.567327  257.573204   61.405684  113.355609
# 1008  33.90074   1008  333.887262  260.531770   64.094504  116.755529
# 1009  33.93415   1009  336.979425  259.524625   53.417008  108.606251
#
#            phi
# 1000  0.029218
# 1001  0.022254
# 1002  0.022075
# 1003  0.048089
# 1004  0.164701
# 1005  0.224768
# 1006  0.137887
# 1007  0.152883
# 1008  0.147806
# 1009  0.156520

# %%
eye_data.ellipse_fits['corneal_reflection'].iloc[1000:1010][minimum_columns]
# Out:
#           time  frame    center_x    center_y     height      width       phi
# 1000  33.63624   1000  316.341802  261.749099   7.948651   7.938827 -0.609278
# 1001  33.66730   1001  315.398135  264.076021   8.345494   9.039955 -0.304189
# 1002  33.70073   1002  313.885466  265.167497   8.330875   9.020216 -0.105195
# 1003  33.73399   1003  311.749787  274.908992  10.896441   9.881648  0.638475
# 1004  33.76739   1004  298.427086  290.425253   9.759468   8.991445  0.727528
# 1005  33.80065   1005  301.702476  286.918579   5.339119   4.724005  0.360549
# 1006  33.83423   1006  303.060707  280.932043   7.298015   5.699418 -0.643577
# 1007  33.86727   1007  300.136221  279.866754   9.454831  10.566762 -0.717665
# 1008  33.90074   1008  304.657713  278.692249   9.461792   8.127531  0.573396
# 1009  33.93415   1009  303.197387  279.973370   8.396875  11.272804 -0.199928

# %%
extra_columns = ['area','normalized_area','likely_blinks',]

# %%
eye_data.ellipse_fits['pupil'].iloc[1000:1010][minimum_columns + extra_columns]
# Out:
#           time  frame    center_x    center_y     height      width       phi  \
# 1000  33.63624   1000  339.732759  230.518579  34.502814  39.533141  0.470115
# 1001  33.66730   1001  338.924015  233.176245  34.576404  39.703893  0.277948
# 1002  33.70073   1002  337.502486  235.067322  34.485627  39.517550  0.274934
# 1003  33.73399   1003  339.843984  252.611272  32.953469  38.286381 -0.123077
# 1004  33.76739   1004  320.118083  262.904844  34.529345  38.356236 -0.047023
# 1005  33.80065   1005  319.748773  256.596288  31.254177  36.309381  0.355990
# 1006  33.83423   1006  326.132982  256.762756  29.349989  37.452898  0.246259
# 1007  33.86727   1007  321.294875  249.853658  30.650049  37.362222  0.174324
# 1008  33.90074   1008  324.264072  252.185895  33.870158  38.371523  0.074987
# 1009  33.93415   1009  325.621861  254.458053  33.506604  38.071494  0.357437
#
#              area  normalized_area  likely_blinks
# 1000  4909.898510         0.349786          False
# ...
