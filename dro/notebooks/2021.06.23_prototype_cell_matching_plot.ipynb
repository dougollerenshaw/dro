# %%
from visual_behavior.visualization.qc import single_cell_across_experiments as scae
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
scae.make_cell_matching_across_experiment_plot(cell_specimen_id=1086586968, experiment_id_to_highlight=992870935)
# Out:
# making plot for cell_specimen_id = 1086586968
# ...
# populating plot axes for each experiment: 100%|██████████| 8/8 [00:04<00:00,  1.88it/s]

# %%
scae.make_cell_matching_across_experiment_plot(cell_specimen_id=1086586968, experiment_id_to_highlight=993344852)
# Out:
# making plot for cell_specimen_id = 1086586968
# ...
# populating plot axes for each experiment: 100%|██████████| 8/8 [00:04<00:00,  1.98it/s]

# %%
scae.make_cell_matching_across_experiment_plot(cell_specimen_id=1086490017, experiment_id_to_highlight=775614751)
# Out:
# making plot for cell_specimen_id = 1086490017
# ...
# populating plot axes for each experiment: 100%|██████████| 4/4 [00:01<00:00,  2.72it/s]

# %%
scae.make_cell_matching_across_experiment_plot(cell_specimen_id=1086490017, experiment_id_to_highlight=796106850)
# Out:
# making plot for cell_specimen_id = 1086490017
# ...
# populating plot axes for each experiment: 100%|██████████| 4/4 [00:01<00:00,  2.27it/s]

# %%
scae.make_cell_matching_across_experiment_plot(cell_specimen_id=1086586967, experiment_id_to_highlight=989610990)
# Out:
# making plot for cell_specimen_id = 1086586967
# ...
# populating plot axes for each experiment: 100%|██████████| 6/6 [00:02<00:00,  2.72it/s]
