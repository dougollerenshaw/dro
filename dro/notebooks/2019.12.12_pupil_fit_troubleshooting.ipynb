# %%
from visual_behavior import utilities as vbu
import visual_behavior.plotting as vbp
from visual_behavior.utilities import EyeTrackingData
from visual_behavior import database as db
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
import time
import seaborn as sns
import matplotlib.patches as patches

from scipy import stats

from multiprocessing import Pool

from dro.modules import eye_tracking as et
from dro.modules import plotting as plot_utils

# %%
# %matplotlib notebook
# %widescreen
# Out:
# <style>.container { width:100% !important; }</style>

# %%
osid = 939868908
ed = et.open_eye_data(osid)
# Out:
# opening eye data for osid = 939868908

# %%
def has_dlc_file(osid):
    return 'EyeDlcOutputFile' in list(db.get_well_known_files(osid)['name'])

def get_raw_points_path(osid):
    wkf = db.get_well_known_files(osid).set_index('name')
    return os.path.join(wkf.loc['EyeDlcOutputFile']['storage_directory'],wkf.loc['EyeDlcOutputFile']['filename'])

def get_ellipse_fit_path(osid):
    wkf = db.get_well_known_files(osid).set_index('name')
    return os.path.join(wkf.loc['EyeTracking Ellipses']['storage_directory'],wkf.loc['EyeTracking Ellipses']['filename'])

def get_raw_points(osid):
    if has_dlc_file(osid):
        raw_points = pd.read_hdf(get_raw_points_path(osid))
    return raw_points

# %%
raw_points = get_raw_points(osid)
raw_points.head()
# Out:
# scorer    DeepCut_resnet50_universal_eye_trackingJul10shuffle1_1030000  \
# bodyparts                                                          cr1
# coords                                                               x
# 0                                                 286.554505
# 1                                                 286.543419
# 2                                                 286.446967
# 3                                                 286.026124
# 4                                                 285.662982
#
# scorer                                                               \
# bodyparts                                cr2
# coords              y likelihood           x           y likelihood
# 0          176.528818   0.977731  286.190393  180.664786   0.972303
# 1          175.962367   0.979474  286.266818  180.290675   0.975937
# 2          177.157185   0.964974  286.060585  181.076132   0.952341
# ...

# %%
def make_plot(ed, initial_frame):
#     raw_points = get_raw_points(osid)
    fig,ax=plt.subplots(1,5,figsize=(15,3))

    
    for ii,frame in enumerate(range(initial_frame-2,initial_frame+3)):
        ax[ii].imshow(ed.get_annotated_frame(frame))

#         pupil_columns = sorted([c for c in np.unique(np.array(raw_points.columns.get_level_values(1))) if c.startswith('pupil')])
#         palette = sns.color_palette("hls", len(pupil_columns))
#         for c,pupil_column in enumerate(pupil_columns):
#             dft = raw_points[raw_points.columns.get_level_values(0)[0]][pupil_column]
#             ax[ii].plot(dft.loc[frame]['x'],dft.loc[frame]['y'],marker='o',color='blue',alpha=0.75,markersize=8)

#         eye_columns = sorted([c for c in np.unique(np.array(raw_points.columns.get_level_values(1))) if c.startswith('eye')])
#         palette = sns.color_palette("hls", len(eye_columns))
#         for c,eye_column in enumerate(eye_columns):
#             dft = raw_points[raw_points.columns.get_level_values(0)[0]][eye_column]
#             ax[ii].plot(dft.loc[frame]['x'],dft.loc[frame]['y'],marker='o',color='red',alpha=0.75,markersize=8)

        ax[ii].set_title('frame = {}'.format(frame))
        ax[ii].axis('off')
    fig.tight_layout()
    plt.subplots_adjust(top=0.9,hspace=0,wspace=0)
    fig.suptitle('ophys_session_id = {}'.format(osid))
    return fig,ax

# %%
make_plot(ed, initial_frame = 120765);
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %% [markdown]
# ## peter regenerated ellipse fits for session 808092249

# %%
osid = 808092249
ed = et.open_eye_data(osid)
# Out:
# opening eye data for osid = 808092249

# %%
ed.ellipse_fits['pupil'].loc[120765][['width','height']]
# Out:
# width     49.9081
# height    44.5034
# Name: 120765, dtype: object

# %%
ed.ellipse_fits['eye'].loc[120765][['width','height']]
# Out:
# width     97.4625
# height    76.1693
# Name: 120765, dtype: object

# %%
make_plot(ed, initial_frame = 120765);
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
ed.ellipse_fit_path = '/allen/programs/braintv/workgroups/cortexmodels/peterl/ForWayne/808092249_video-1DeepCut_resnet50_universal_eye_trackingJul10shuffle1_1030000_ellipse.h5'
# ed.ellipse_fit_path = '/allen/aibs/technology/waynew/eye/phase3/29intermediate/851438454_video-1DeepCut_resnet50_universal_eye_trackingJul10shuffle1_1030000_ellipse.h5'
for dataset in ['pupil', 'eye', 'cr']:
    ed.ellipse_fits[dataset] = ed.get_eye_data_from_file(ed.ellipse_fit_path, dataset=dataset, timestamps=ed.sync_timestamps['eye'])

# %%
ed.ellipse_fits['pupil'].loc[120765][['width','height']]
# Out:
# width     49.908067
# height    44.503423
# Name: 120765, dtype: float64

# %%
ed.ellipse_fits['eye'].loc[120765][['width','height']]
# Out:
# width     156.939797
# height    122.786368
# Name: 120765, dtype: float64

# %%
make_plot(ed, initial_frame = 120765);
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %% [markdown]
# ## 851438454

# %%
osid = 851438454
ed = EyeTrackingData(osid, ellipse_fit_path = '/allen/aibs/technology/waynew/eye/phase3/29intermediate/851438454_video-1DeepCut_resnet50_universal_eye_trackingJul10shuffle1_1030000_ellipse.h5', data_source='filesystem')

# %%
make_plot(ed, initial_frame = 120765);
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
# ed.ellipse_fit_path = '/allen/programs/braintv/workgroups/cortexmodels/peterl/ForWayne/808092249_video-1DeepCut_resnet50_universal_eye_trackingJul10shuffle1_1030000_ellipse.h5'
ed.ellipse_fit_path = '/allen/aibs/technology/waynew/eye/phase3/29intermediate/851438454_video-1DeepCut_resnet50_universal_eye_trackingJul10shuffle1_1030000_ellipse.h5'
for dataset in ['pupil', 'eye', 'cr']:
    ed.ellipse_fits[dataset] = ed.get_eye_data_from_file(ed.ellipse_fit_path, dataset=dataset, timestamps=ed.sync_timestamps['eye'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-62f3a1fbfb51> in <module>
#       1 # ed.ellipse_fit_path = '/allen/programs/braintv/workgroups/cortexmodels/peterl/ForWayne/808092249_video-1DeepCut_resnet50_universal_eye_trackingJul10shuffle1_1030000_ellipse.h5'
# ----> 2 ed.ellipse_fit_path = '/allen/aibs/technology/waynew/eye/phase3/29intermediate/851438454_video-1DeepCut_resnet50_universal_eye_trackingJul10shuffle1_1030000_ellipse.h5'
#       3 for dataset in ['pupil', 'eye', 'cr']:
#       4     ed.ellipse_fits[dataset] = ed.get_eye_data_from_file(ed.ellipse_fit_path, dataset=dataset, timestamps=ed.sync_timestamps['eye'])
#
# AttributeError: 'NoneType' object has no attribute 'ellipse_fit_path'
