# %% [markdown]
# # examples of mongo interaction
# Here are some simple examples of how to interact with existing mongo databases

# %%
from visual_behavior import database
import pandas as pd

# %% [markdown]
# ## visual behavior database functions

# %%
vb_db = database.Database('visual_behavior_data')

# %%
dir(vb_db)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_db_names',
#  'behavior_analysis',
#  'behavior_data',
#  'change_detection_pilot',
#  'client',
#  'close',
#  'cluster_outputs',
#  'config',
#  'database',
#  'database_names',
#  'eyetracking',
#  'lick_detection_validation',
#  'local',
#  'null',
#  'ophys_analysis',
#  'ophys_glm',
#  'ophys_glm_xarrays',
#  'ophys_population_analysis',
#  'ophys_qc',
#  'qc_plots',
#  'query',
#  'release_behavior_data',
#  'sample_db',
#  'sdk_validation',
#  'temp_cache']

# %%
conn = vb_db['ophys_glm']
collection = conn['results_summary']
df = pd.DataFrame(list(collection.find({'cell_specimen_id': 817103095})))

# %%
df
# Out:
#                            _id        dropout  variance_explained  \
# 0     5f218aec952f973def1b984b           Full            0.030641
# 1     5f218aec952f973def1b984c      intercept            0.030031
# 2     5f218aec952f973def1b984d           time            0.030752
# 3     5f218aec952f973def1b984e      pre_licks            0.031374
# 4     5f218aec952f973def1b984f     post_licks            0.030858
# ...                        ...            ...                 ...
# 1218  5fb87b427f39a9384cf672fe    single-time            0.000102
# 1219  5fb87b427f39a9384cf672ff  single-visual            0.039049
# 1220  5fb87b427f39a9384cf67300           task            0.053294
# 1221  5fb87b427f39a9384cf67301           time            0.053597
# 1222  5fb87b427f39a9384cf67302         visual            0.021064
#
#       fraction_change_from_full  absolute_change_from_full  cell_specimen_id  \
# 0                      0.000000                   0.000000         817103095
# ...

# %% [markdown]
# ## mouse seeks:

# %%
mouseseeks_db = database.Database('mouseseeks')

# %%
mouseseeks_db.database_names
# Out:
# ['db', 'dev', 'qc', 'local']

# %%
ms_qc_collection = mouseseeks_db['qc']

# %%
ms_qc_collection.list_collection_names()
# Out:
# ['images', 'metrics', 'project_sets', 'reports', 'system.indexes']
