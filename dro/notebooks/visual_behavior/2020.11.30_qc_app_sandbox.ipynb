# %%
import visual_behavior.visualization.qc.data_loading as dl
import visual_behavior.data_access.loading as loading
import pandas as pd

# %%
# %%time
container_df = dl.build_container_df()
filtered_container_list = dl.get_filtered_ophys_container_ids()  # NOQA F841
container_subsets = pd.read_csv('/home/dougo/spreadsheet_map.csv')
res = container_df.query('container_id in @filtered_container_list')
table = res.merge(container_subsets, left_on='container_id', right_on='container_id', how='left')
# Out:
# CPU times: user 9.41 s, sys: 24.2 ms, total: 9.43 s
# Wall time: 9.46 s

# %%
container_df.iloc[0]['session_0']
# Out:
# 'OPHYS_1_images_A 930996080'

# %%
table
# Out:
#      container_id container_workflow_state first_acquistion_date  \
# 0      1026722876             container_qc            2019-08-23
# 1      1026722873           postprocessing            2019-08-22
# 2      1026722870             container_qc            2019-08-22
# 3      1026722867           postprocessing            2019-08-22
# 4      1026722864           postprocessing            2019-08-23
# ..            ...                      ...                   ...
# 235     803589437             container_qc            2019-01-09
# 236     803517529             container_qc            2019-01-09
# 237     803516615             container_qc            2019-02-12
# 238     791352433             container_qc            2018-12-10
# 239     782536745           postprocessing            2018-11-08
#
#                  project_code                      driver_line  \
# 0    VisualBehaviorMultiscope                   [Vip-IRES-Cre]
# ...

# %%
res['first_acquistion_date'].max()
# Out:
# '2020-02-25'

# %%
et = loading.get_filtered_ophys_experiment_table()
et['date_of_acquisition'].max()
# Out:
# '2020-10-01 17:28:23.000000'

# %%
et
# Out:
#                      ophys_session_id  behavior_session_id  container_id  \
# ophys_experiment_id
# 953659743                   952430817            952554548    1018028345
# 953659745                   952430817            952554548    1018028339
# 953659749                   952430817            952554548    1018028354
# 953659752                   952430817            952554548    1018028357
# 958527474                   954954402            953982960    1018028339
# ...                               ...                  ...           ...
# 929655737                   929255311            929341697    1026722867
# 929655732                   929255311            929341697    1026722870
# 929655728                   929255311            929341697    1026722854
# 929655730                   929255311            929341697    1026722873
# 929655722                   929255311            929341697    1026722858
#
# ...

# %%
dl_et = dl.get_filtered_ophys_experiment_table()

# %%
dl_et
# Out:
#       ophys_experiment_id  ophys_session_id  behavior_session_id  \
# 1               953659743         952430817            952554548
# 2               953659745         952430817            952554548
# 4               953659749         952430817            952554548
# 5               953659752         952430817            952554548
# 8               958527474         954954402            953982960
# ...                   ...               ...                  ...
# 2917            929655737         929255311            929341697
# 2918            929655732         929255311            929341697
# 2919            929655728         929255311            929341697
# 2920            929655730         929255311            929341697
# 2921            929655722         929255311            929341697
#
#       container_id              project_code container_workflow_state  \
# 1       1018028345  VisualBehaviorMultiscope             container_qc
# ...

# %%
import datetime

# %%
datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2020-12-01 14:31:37'
