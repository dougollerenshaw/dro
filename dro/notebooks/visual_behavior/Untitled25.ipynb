# %%
import visual_behavior.database as db
import pandas as pd

conn = db.Database('visual_behavior_data')
# get existing container table from database
database = 'ophys_qc'
collection = conn[database]['container_qc_records']
container_records = pd.DataFrame(list(collection.find({'username':'dougo'}))).sort_values(by='timestamp', ascending=False)

container_records
# Out:
#                                  _id            timestamp username  \
# 58  9cc3498f9b5c47a384a782353677b7ff  2021-01-07 13:53:48    dougo
# 57  c389a7aa86d8406f9412b09bcfb53367  2021-01-07 13:50:53    dougo
# 56  03a1003e054a495b99429ed72327a0fb  2021-01-07 13:42:38    dougo
# 55  db22b86dfcad4277a411569dbf7c3161  2021-01-07 13:36:25    dougo
# 54  8753af772430410d929c6ebfb1769d70  2021-01-07 13:24:11    dougo
# 53  7b3501199cdd43b8a2c839c37900390a  2021-01-07 13:22:55    dougo
# 52  d11e6a9b533e4cc9a065ca579221dc0e  2021-01-07 13:21:09    dougo
# 51  96fe0c9863e34d4189177e0747830f1d  2021-01-07 13:06:58    dougo
# 50  e683c10b0e864623aa2e5d204637d6f3  2021-01-07 13:05:52    dougo
# 49  f2329dcb439440b2bcae7c84df1fcd2a  2021-01-07 13:04:39    dougo
# 48  0ffd209310454a83bca657ed3805a7f6  2021-01-07 13:03:27    dougo
# 47  9be19f081009497292d47a6eb9df38bc  2020-12-10 16:29:28    dougo
# 46  6b345451412344d284b013abfdae737d  2020-12-10 16:28:03    dougo
# ...

# %%
src = r'\\allen\programs\braintv\production\visualbehavior\prod0\specimen_813703544\ophys_session_843049997\ophys_experiment_843519218\processed\motion_preview.10x.mp4'.replace('\\','/')
src
# Out:
# '//allen/programs/braintv/production/visualbehavior/prod0/specimen_813703544/ophys_session_843049997/ophys_experiment_843519218/processed/motion_preview.10x.mp4'

# %%
dst =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6c6e7500c163> in <module>
# ----> 1 dst
#
# NameError: name 'dst' is not defined
