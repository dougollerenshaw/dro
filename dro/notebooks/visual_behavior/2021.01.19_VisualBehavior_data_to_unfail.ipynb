# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from visual_behavior import database as db

pd.set_option('display.max_columns', 500)

import visual_behavior.visualization.utils as utils
import visual_behavior.data_access.loading as loading
import visual_behavior.data_access.filtering as filtering
import visual_behavior.ophys.response_analysis.utilities as ut
from visual_behavior.ophys.response_analysis.response_analysis import ResponseAnalysis

# %% [markdown]
# ## define the acceptable failure tags

# %%
acceptable_fail_tags = [
    'd_prime_peak', # this means the animal didn't perform the task well - was not discriminating
    'num_contingent_trials', # this also means the animal didn't perform the task well - likely too many aborted trials
    'validate_omitted_flashes_are_omitted', # this was due to a recurrent camstim bug that turned out having little effect on data integrity
]

# %% [markdown]
# ## load the experiment_table

# %%
experiment_table = loading.get_filtered_ophys_experiment_table(include_failed_data=True)

# %%
experiment_table['experiment_workflow_state'].unique()
# Out:
# array(['failed', 'passed'], dtype=object)

# %%
experiment_table.query('experiment_workflow_state == "failed"').sample(5)
# Out:
#                      ophys_session_id  behavior_session_id  container_id  \
# ophys_experiment_id
# 875808255                   875259383            875471358    1018027605
# 1049853339                 1049740675           1049767272    1046576791
# 929603823                   927620400            927764490    1018028328
# 845777913                   845235947            845404780    1018027567
# 988542657                   987896411            988099332     975371413
#
#                                  project_code container_workflow_state  \
# ophys_experiment_id
# 875808255            VisualBehaviorMultiscope             container_qc
# 1049853339           VisualBehaviorMultiscope                  holding
# 929603823            VisualBehaviorMultiscope                   failed
# 845777913            VisualBehaviorMultiscope                   failed
# 988542657                VisualBehaviorTask1B             container_qc
#
#                     experiment_workflow_state                   session_name  \
# ophys_experiment_id
# 875808255                              failed         20190524_449653_Ophys6
# 1049853339                             failed   20200911_523922_ophys2retake
# 929603823                              failed       20190820_Ophys4_retake_4
# 845777913                              failed  20190403_429956_Ophys5Passive
# 988542657                              failed       20191120_477202_6imagesA
#
#                                  session_type equipment_name  \
# ophys_experiment_id
# 875808255                    OPHYS_6_images_A         MESO.1
# 1049853339           OPHYS_2_images_A_passive         MESO.1
# 929603823                    OPHYS_4_images_B         MESO.1
# 845777913                    OPHYS_4_images_B         MESO.1
# 988542657                    OPHYS_6_images_A        CAM2P.3
#
#                             date_of_acquisition  isi_experiment_id  \
# ophys_experiment_id
# 875808255            2019-05-24 12:37:09.824183          846102910
# 1049853339           2020-09-11 11:47:43.237104         1025266430
# 929603823            2019-08-20 12:39:37.863363          847875381
# 845777913            2019-04-03 09:01:20.000000          802369734
# 988542657            2019-11-20 21:00:49.000000          918315422
#
#                      specimen_id sex  age_in_days  \
# ophys_experiment_id
# 875808255              837628436   M        126.0
# 1049853339            1022744256   M        179.0
# 929603823              840542948   M        193.0
# 845777913              791855403   F        173.0
# 988542657              910248639   M        171.0
#
#                                                          full_genotype  \
# ophys_experiment_id
# 875808255                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 1049853339               Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 929603823            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 845777913                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 988542657                Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
#
#                                       reporter_line  \
# ophys_experiment_id
# 875808255            ['Ai148(TIT2L-GC6f-ICL-tTA2)']
# 1049853339           ['Ai148(TIT2L-GC6f-ICL-tTA2)']
# 929603823                    ['Ai93(TITL-GCaMP6f)']
# 845777913            ['Ai148(TIT2L-GC6f-ICL-tTA2)']
# 988542657            ['Ai148(TIT2L-GC6f-ICL-tTA2)']
#
#                                              driver_line  imaging_depth  \
# ophys_experiment_id
# 875808255                               ['Vip-IRES-Cre']             79
# 1049853339                              ['Vip-IRES-Cre']            227
# 929603823            ['Slc17a7-IRES2-Cre', 'Camk2a-tTA']            171
# 845777913                               ['Vip-IRES-Cre']             75
# 988542657                               ['Sst-IRES-Cre']            275
#
#                     targeted_structure  published_at  super_container_id  \
# ophys_experiment_id
# 875808255                         VISl           NaN           837628436
# 1049853339                        VISl           NaN          1022744256
# 929603823                         VISl           NaN           840542948
# 845777913                         VISp           NaN           791855403
# 988542657                         VISp           NaN           910248639
#
#                               cre_line              session_tags  \
# ophys_experiment_id
# 875808255                 Vip-IRES-Cre                       NaN
# 1049853339                Vip-IRES-Cre                       NaN
# 929603823            Slc17a7-IRES2-Cre                       NaN
# 845777913                 Vip-IRES-Cre  mesoscope_pilot_datacube
# 988542657                 Sst-IRES-Cre                       NaN
#
#                                                           failure_tags  \
# ophys_experiment_id
# 875808255                           d_prime_peak,num_contingent_trials
# 1049853339           percent_change_intensity,percent_change_intens...
# 929603823                                                          NaN
# 845777913                                                          NaN
# 988542657                                                 d_prime_peak
#
#                      session_type_exposure_number  \
# ophys_experiment_id
# 875808255                                       0
# 1049853339                                      1
# 929603823                                       2
# 845777913                                       1
# 988542657                                       1
#
#                      prior_exposures_to_image_set  \
# ophys_experiment_id
# 875808255                                    17.0
# 1049853339                                   49.0
# 929603823                                     5.0
# 845777913                                     1.0
# 988542657                                     3.0
#
#                      prior_exposures_to_omissions  model_outputs_available  \
# ophys_experiment_id
# 875808255                                     6.0                    False
# 1049853339                                    5.0                    False
# 929603823                                     8.0                    False
# 845777913                                     5.0                    False
# 988542657                                     7.0                    False
#
#                      has_cell_matching          location  has_events  \
# ophys_experiment_id
# 875808255                        False       Vip_VISl_79        True
# 1049853339                        True      Vip_VISl_227        True
# 929603823                        False  Slc17a7_VISl_171       False
# 845777913                         True       Vip_VISp_75        True
# 988542657                        False      Sst_VISp_275       False
#
#                      session_number
# ophys_experiment_id
# 875808255                       6.0
# 1049853339                      2.0
# 929603823                       4.0
# 845777913                       4.0
# 988542657                       6.0

# %% [markdown]
# ## define a function to query mouseseeks to get all experiments that have a given failure tag

# %%
def get_experiments_with_fail_tag(fail_tag):
    '''
    query mouseseeks to get all experiments that have a given failure tag
    note that this will return all experiments with that fail tag, even if it also has other fail tags
    '''
    mouseseeks = db.Database('mouseseeks')
    documents = list(mouseseeks['db']['ophys_session_log'].find({'failure_tags':{"$in":[fail_tag]}}))
    mouseseeks.close()
    return pd.DataFrame(documents)

# %% [markdown]
# ## get all experiments that have any of the acceptable failure tags
# drop duplicates to avoid getting an experiment more than once if it has more than one acceptable

# %%
documents = pd.DataFrame()
# iterate over every acceptable failure tag
for fail_tag in acceptable_fail_tags:
    # get all experiments with this tag
    df = get_experiments_with_fail_tag(fail_tag)
    
    # concatenate with existing list of experiments, then drop duplicates
    documents = pd.concat([documents, df]).drop_duplicates(subset = ['id','specimen_id']).reset_index(drop=True)
documents.sample(5)
# Out:
#                           _id         id  \
# 51   5d5ae73017ec6f430f4419a2  926488384
# 189  5d6fd50917ec6f430f442479  938094182
# 16   5d011e1509ed44852535cdfb  885229423
# 20   5cfe9ab909ed44852535cb79  883619540
# 89   5dbcaaf217ec6f430f444c91  975460534
#
#                                         isi_experiment  \
# 51   {'storage_directory': '/allen/programs/braintv...
# 189  {'storage_directory': '/allen/programs/braintv...
# 16   {'storage_directory': '/allen/programs/braintv...
# 20   {'storage_directory': '/allen/programs/braintv...
# 89   {'storage_directory': '/allen/programs/braintv...
#
#                                 name workflow_state  specimen_id  \
# 51     20190819_453909_Ophys6_retake       uploaded    840542948
# 189  20190904_459773_2imagesApassive       uploaded    854612265
# 16          20190612_442147_1imagesA       uploaded    830896328
# 20          20190610_451787_4imagesB       uploaded    837581585
# 89                20191101_479835_3B       uploaded    920850703
#
#         date_of_acquisition  depth              project_code  area  \
# 51  2019-08-19 11:05:58.134    NaN  VisualBehaviorMultiscope  None
# 189 2019-09-04 15:01:19.000  175.0            VisualBehavior  VISp
# 16  2019-06-12 15:30:43.000   75.0            VisualBehavior  VISp
# 20  2019-06-10 10:58:39.000    NaN  VisualBehaviorMultiscope  None
# 89  2019-11-01 21:51:03.000  175.0      VisualBehaviorTask1B  VISp
#
#                                      storage_directory  \
# 51   /allen/programs/braintv/production/visualbehav...
# 189  /allen/programs/braintv/production/visualbehav...
# 16   /allen/programs/braintv/production/visualbehav...
# 20   /allen/programs/braintv/production/visualbehav...
# 89   /allen/programs/braintv/production/visualbehav...
#
#                                   ophys_parent_session       operator  \
# 51   {'storage_directory': '/allen/programs/braintv...   sara.kivikas
# 189  {'storage_directory': '/allen/programs/braintv...  xana.waughman
# 16   {'storage_directory': '/allen/programs/braintv...       shiellac
# 20   {'storage_directory': '/allen/programs/braintv...     india.kato
# 89   {'storage_directory': '/allen/programs/braintv...          joshl
#
#          rig                                  ophys_experiments  \
# 51    MESO.1  [{'storage_directory': '/allen/programs/braint...
# 189  CAM2P.5  [{'storage_directory': '/allen/programs/braint...
# 16   CAM2P.4  [{'storage_directory': '/allen/programs/braint...
# 20    MESO.1  [{'storage_directory': '/allen/programs/braint...
# 89   CAM2P.5  [{'storage_directory': '/allen/programs/braint...
#
#     external_specimen_name                           genotype  \
# 51                  453909  Slc17a7-IRES2-Cre;Camk2a-tTA;Ai93
# 189                 459773  Slc17a7-IRES2-Cre;Camk2a-tTA;Ai93
# 16                  442147  Chat-IRES-Cre-neo;Chrm2-tdT;Ai162
# 20                  451787  Slc17a7-IRES2-Cre;Camk2a-tTA;Ai93
# 89                  479835  Slc17a7-IRES2-Cre;Camk2a-tTA;Ai93
#
#                                 qc_status  \
# 51   {'status': 'success', 'message': ''}
# 189  {'status': 'success', 'message': ''}
# 16   {'status': 'success', 'message': ''}
# 20   {'status': 'success', 'message': ''}
# 89   {'status': 'success', 'message': ''}
#
#                                           failure_tags  \
# 51   [parent_averaged_depth_image_2, parent_average...
# 189             [validate_omitted_flashes_are_omitted]
# 16                                      [d_prime_peak]
# 20   [percent_change_intensity, percent_change_inte...
# 89               [d_prime_peak, num_contingent_trials]
#
#                                                  flags  \
# 51   [{'lims_id': '926488384', 'notes': 'FLAG:  Hig...
# 189                                                 []
# 16                                                  []
# 20                                                  []
# 89   [{'lims_id': '975542757', 'notes': 'FLAG:  int...
#
#                                              overrides  \
# 51   [{'lims_id': '926488384', 'notes': 'OVERRIDE: ...
# 189  [{'lims_id': '938094182', 'notes': 'OVERRIDE: ...
# 16                                                  []
# 20   [{'lims_id': '884271249', 'notes': 'OVERRIDE: ...
# 89                                                  []
#
#                                             qc_reports  \
# 51   [{'submit_datetime': 2019-08-22 09:17:22.26000...
# 189  [{'submit_datetime': 2019-09-12 13:34:16.68100...
# 16   [{'submit_datetime': 2019-06-13 08:13:17.58200...
# 20   [{'submit_datetime': 2019-06-11 12:12:15.88600...
# 89   [{'submit_datetime': 2019-11-04 09:24:02.14200...
#
#                                         notes        session_tags
# 51                                        NaN                 NaN
# 189                                       NaN                 NaN
# 16                                        NaN  [visbehneuromodax]
# 20   Animal did not behave\r\nintensity drift                 NaN
# 89                                        NaN                 NaN

# %% [markdown]
# ## define a function to check to see if 'failure_tags' contains only acceptable tags

# %%
def only_acceptable_fail_tags_in_record(document, acceptable_fail_tags):
    # checks to see if the experiment had any failure tags beyond those listed as 'acceptable'
    # returns True if all fail tags are in set of acceptible fail tags, False otherwise
    return len(set(document['failure_tags']).union(set(acceptable_fail_tags)) - set(acceptable_fail_tags)) == 0

# %% [markdown]
# ## apply the function, assign boolean output to a column called "only_acceptable_fail_tags"

# %%
documents['only_acceptable_fail_tags'] = documents.apply(
    only_acceptable_fail_tags_in_record, 
    axis=1, 
    acceptable_fail_tags=acceptable_fail_tags
)

# %% [markdown]
# ## Mesoscope sessions
# A mesoscope session consists of 8 experiments
# In some cases, only acceptable fail tags apply to all experiments. This case is straightforward and allows all to be unfailed
# In other cases, at least one experiment had an unacceptable fail tag. But mouseseeks does not, as far as I can tell, track which fail tags were associated with which experiment. For now, we are going to unfail all sessions that have at least one unacceptable fail tag. The individual failed experiments can be removed later.

# %%
len(documents.query('rig == "MESO.1" and only_acceptable_fail_tags == True'))
# Out:
# 7

# %%
len(documents.query('rig == "MESO.1" and only_acceptable_fail_tags == False'))
# Out:
# 19

# %% [markdown]
# ## Final conditions for unfailing:
# * Session has only acceptable fail tags
# *or*
# * Session is a mesoscope session with at least one acceptable fail tag (individual failing experiments to be removed later)

# %%
def unfail(document):
    return document['only_acceptable_fail_tags'] or document['rig'] == "MESO.1"
documents['unfail'] = documents.apply(unfail, axis=1)
documents['unfail'].value_counts()
# Out:
# True     151
# False     42
# Name: unfail, dtype: int64

# %% [markdown]
# ## Save the sessions to unfail to a CSV file

# %%
sessions_to_unfail = documents.query('unfail').rename(columns={'id': 'ophys_session_id'})

columns_to_save = [
    'ophys_session_id',
    'specimen_id',
    'date_of_acquisition',
    'depth',
    'project_code',
    'area',
    'rig',
    'failure_tags',
    'only_acceptable_fail_tags',
    'unfail',
]
sessions_to_unfail[columns_to_save].to_csv('/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/2021.01.20_sessions_to_unfail.csv', index=False)

# %%
sessions_to_unfail[columns_to_save]
# Out:
#      ophys_session_id  specimen_id date_of_acquisition  depth  \
# 0           856295914    820871408 2019-04-24 16:49:34  375.0
# 1           857232455    820871408 2019-04-25 17:20:49  375.0
# 3           857202651    823826986 2019-04-25 17:00:04  175.0
# 6           863527124    823826986 2019-05-06 20:07:55  175.0
# 7           865275609    821470815 2019-05-09 18:12:00  175.0
# ..                ...          ...                 ...    ...
# 185         851426367    823826986 2019-04-15 15:31:58  175.0
# 189         938094182    854612265 2019-09-04 15:01:19  175.0
# 190         973776534    920850703 2019-10-29 21:27:12  175.0
# 191        1010897308    991762388 2020-02-28 16:38:10  175.0
# 192         897687788    837622017 2019-06-29 17:01:59  175.0
#
#              project_code  area      rig  \
# 0          VisualBehavior  VISp  CAM2P.3
# 1          VisualBehavior  VISp  CAM2P.3
# 3          VisualBehavior  VISp  CAM2P.4
# 6          VisualBehavior  VISp  CAM2P.4
# 7          VisualBehavior  VISp  CAM2P.4
# ..                    ...   ...      ...
# 185        VisualBehavior  VISp  CAM2P.4
# 189        VisualBehavior  VISp  CAM2P.5
# 190  VisualBehaviorTask1B  VISp  CAM2P.5
# 191  VisualBehaviorTask1B  VISp  CAM2P.4
# 192        VisualBehavior  VISp  CAM2P.5
#
#                                failure_tags  only_acceptable_fail_tags  unfail
# 0                            [d_prime_peak]                       True    True
# 1                            [d_prime_peak]                       True    True
# 3                            [d_prime_peak]                       True    True
# 6                            [d_prime_peak]                       True    True
# 7                            [d_prime_peak]                       True    True
# ..                                      ...                        ...     ...
# 185  [validate_omitted_flashes_are_omitted]                       True    True
# 189  [validate_omitted_flashes_are_omitted]                       True    True
# 190  [validate_omitted_flashes_are_omitted]                       True    True
# 191  [validate_omitted_flashes_are_omitted]                       True    True
# 192  [validate_omitted_flashes_are_omitted]                       True    True
#
# [151 rows x 10 columns]

# %%
mouseseeks = db.Database('mouseseeks')
documents = list(mouseseeks['db']['ophys_session_log'].find({'id':842023261}))
mouseseeks.close()

# %%
documents[0]['failure_tags']
# Out:
# ['z_drift_corr_um_diff']

# %%
documents[0]
# Out:
# {'_id': ObjectId('5c9b9a9309ed4485253592f5'),
#  'id': 842023261,
#  'isi_experiment': {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/isi_experiment_802369734/',
#   'workflow_state': 'passed',
#   'name': '429956_20190102',
#   'id': 802369734},
#  'name': '20190327_429956_Ophys1',
#  'workflow_state': 'uploaded',
#  'specimen_id': 791855403,
#  'date_of_acquisition': datetime.datetime(2019, 3, 27, 8, 37, 11),
#  'depth': None,
#  'project_code': 'VisualBehaviorMultiscope',
#  'area': None,
#  'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/',
#  'ophys_parent_session': {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_841682738/',
#   'workflow_state': 'uploaded',
#   'name': '20190326_429956_ophys1',
#   'id': 841682738},
#  'operator': 'sams',
#  'rig': 'MESO.1',
#  'ophys_experiments': [{'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/ophys_experiment_842545454/',
#    'workflow_state': 'passed',
#    'name': '20190327_429956_Ophys1_VISp_0_0_211',
#    'id': 842545454},
#   {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/ophys_experiment_842545456/',
#    'workflow_state': 'passed',
#    'name': '20190327_429956_Ophys1_VISp_0_0_150',
#    'id': 842545456},
#   {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/ophys_experiment_842545458/',
#    'workflow_state': 'passed',
#    'name': '20190327_429956_Ophys1_VISp_0_0_338',
#    'id': 842545458},
#   {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/ophys_experiment_842545462/',
#    'workflow_state': 'passed',
#    'name': '20190327_429956_Ophys1_VISp_0_0_71',
#    'id': 842545462},
#   {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/ophys_experiment_842545466/',
#    'workflow_state': 'passed',
#    'name': '20190327_429956_Ophys1_VISl_100_100_196',
#    'id': 842545466},
#   {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/ophys_experiment_842545468/',
#    'workflow_state': 'passed',
#    'name': '20190327_429956_Ophys1_VISl_100_100_140',
#    'id': 842545468},
#   {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/ophys_experiment_842545470/',
#    'workflow_state': 'failed',
#    'name': '20190327_429956_Ophys1_VISl_100_100_300',
#    'id': 842545470},
#   {'storage_directory': '/allen/programs/braintv/production/neuralcoding/prod0/specimen_791855403/ophys_session_842023261/ophys_experiment_842545472/',
#    'workflow_state': 'passed',
#    'name': '20190327_429956_Ophys1_VISl_100_100_73',
#    'id': 842545472}],
#  'external_specimen_name': '429956',
#  'genotype': 'Vip-IRES-Cre;Ai148',
#  'qc_status': {'status': 'success', 'message': ''},
#  'notes': 'ophys_1',
#  'session_tags': ['mesoscope_pilot_datacube'],
#  'failure_tags': ['z_drift_corr_um_diff'],
#  'flags': [{'lims_id': '842023261',
#    'notes': 'FLAG:  negative?',
#    'metric': 'nb_dropped_eye_tracking_frames'},
#   {'lims_id': '842023261',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'isi_ophys_overlay'},
#   {'lims_id': '842545454',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'epilepsy_probability_plot'},
#   {'lims_id': '842545456',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'epilepsy_probability_plot'},
#   {'lims_id': '842545458',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'epilepsy_probability'},
#   {'lims_id': '842545462',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'epilepsy_probability'},
#   {'lims_id': '842545466',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'epilepsy_probability'},
#   {'lims_id': '842545468',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'epilepsy_probability'},
#   {'lims_id': '842545470',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'epilepsy_probability'},
#   {'lims_id': '842545472',
#    'notes': 'FLAG:  metric not valid',
#    'metric': 'epilepsy_probability'},
#   {'lims_id': '842545458',
#    'notes': "FLAG:  peaks aren't super defined",
#    'metric': 'corr_z_drift_score_plot'},
#   {'lims_id': '842545462',
#    'notes': 'FLAG:  chaotic ',
#    'metric': 'corr_z_drift_score_plot'},
#   {'lims_id': '842545466',
#    'notes': 'FLAG:  no clear peaks',
#    'metric': 'corr_z_drift_score_plot'},
#   {'lims_id': '842545470',
#    'notes': 'FLAG:  no clear peaks',
#    'metric': 'corr_z_drift_score_plot'},
#   {'lims_id': '842545458',
#    'notes': 'FLAG:  high exposure',
#    'metric': 'motion_corr_physio_start'},
#   {'lims_id': '842545458',
#    'notes': 'FLAG:  28',
#    'metric': 'z_drift_corr_start_frame'},
#   {'lims_id': '842545458',
#    'notes': 'FLAG:  10',
#    'metric': 'z_drift_corr_frame_diff'},
#   {'lims_id': '842545458',
#    'notes': 'FLAG:  7.5',
#    'metric': 'z_drift_corr_um_diff'},
#   {'lims_id': '842545466',
#    'notes': 'FLAG:  31',
#    'metric': 'z_drift_corr_end_frame'},
#   {'lims_id': '842545466',
#    'notes': 'FLAG:  4',
#    'metric': 'z_drift_corr_frame_diff'},
#   {'lims_id': '842545470',
#    'notes': 'FLAG:  29',
#    'metric': 'z_drift_corr_start_frame'},
#   {'lims_id': '842545470',
#    'notes': 'FLAG:  44',
#    'metric': 'z_drift_corr_end_frame'},
#   {'lims_id': '842545470',
#    'notes': 'FLAG:  -15',
#    'metric': 'z_drift_corr_frame_diff'}],
#  'overrides': [{'lims_id': '842545454',
#    'notes': 'OVERRIDE:  metric not valid',
#    'metric': 'target_match'},
#   {'lims_id': '842545456',
#    'notes': 'OVERRIDE:  metric not valid',
#    'metric': 'target_match'},
#   {'lims_id': '842545458',
#    'notes': 'OVERRIDE:  metric not valid',
#    'metric': 'target_match'},
#   {'lims_id': '842545462',
#    'notes': 'OVERRIDE:  metric not valid',
#    'metric': 'target_match'},
#   {'lims_id': '842545466',
#    'notes': 'OVERRIDE:  metric not valid',
#    'metric': 'target_match'},
#   {'lims_id': '842545468',
#    'notes': 'OVERRIDE:  metric not valid',
#    'metric': 'target_match'},
#   {'lims_id': '842545470',
#    'notes': 'OVERRIDE:  metric not valid',
#    'metric': 'target_match'},
#   {'lims_id': '842545472',
#    'notes': 'OVERRIDE:  metric not valid',
#    'metric': 'target_match'},
#   {'lims_id': '842545466',
#    'notes': 'OVERRIDE:  3',
#    'metric': 'z_drift_corr_um_diff'},
#   {'lims_id': '842545470',
#    'notes': 'OVERRIDE:  11.25',
#    'metric': 'z_drift_corr_um_diff'}],
#  'qc_reports': [{'submit_datetime': datetime.datetime(2019, 6, 21, 10, 44, 40, 945000),
#    'qc_reviewer': 'sara.kivikas',
#    'qc_report_html': '<div class="qc_report_page">\n\n    <div>\n        <div class="panel-group">\n\t<div class="panel panel-default">\n\t\t<div class="panel-heading">LIMS:  Ophys Session\n\t\t\t<span class="pull-right clickable"><i class="glyphicon glyphicon-chevron-up"></i></span>\n\t\t</div>\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_session_id">842023261</td>\n        </tr>\n        \n        <tr>\n            <td>Name</td>\n            <td class="lims_ophys_session_name">20190327_429956_Ophys1</td>\n        </tr>\n        \n        <tr>\n            <td>Workflow State</td>\n            <td class="lims_ophys_session_workflow_state">uploaded</td>\n        </tr>\n        \n        <tr>\n            <td>Rig</td>\n            <td class="lims_ophys_session_rig">MESO.1</td>\n        </tr>\n        \n        <tr>\n            <td>Operator</td>\n            <td class="lims_ophys_session_operator">sams</td>\n        </tr>\n        \n        <tr>\n            <td>Mouse ID</td>\n            <td class="lims_ophys_session_external_specimen_name">429956</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t</div>\n</div>\n    </div>\n\n    <div>\n        <div class="panel-group">\n\t<div class="panel panel-default">\n\t\t<div class="panel-heading">LIMS:  Ophys Experiment\n\t\t\t<span class="pull-right clickable"><i class="glyphicon glyphicon-chevron-up"></i></span>\n\t\t</div>\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545454</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class="lims_ophys_experiment_depth">211</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545456</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class="lims_ophys_experiment_depth">150</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545458</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class ...
#   {'submit_datetime': datetime.datetime(2019, 7, 3, 14, 54, 51, 624000),
#    'qc_reviewer': 'sams',
#    'qc_report_html': '<div class="qc_report_page">\n\n    <div>\n        <div class="panel-group">\n\t<div class="panel panel-default">\n\t\t<div class="panel-heading">LIMS:  Ophys Session\n\t\t\t<span class="pull-right clickable"><i class="glyphicon glyphicon-chevron-up"></i></span>\n\t\t</div>\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_session_id">842023261</td>\n        </tr>\n        \n        <tr>\n            <td>Name</td>\n            <td class="lims_ophys_session_name">20190327_429956_Ophys1</td>\n        </tr>\n        \n        <tr>\n            <td>Workflow State</td>\n            <td class="lims_ophys_session_workflow_state">uploaded</td>\n        </tr>\n        \n        <tr>\n            <td>Rig</td>\n            <td class="lims_ophys_session_rig">MESO.1</td>\n        </tr>\n        \n        <tr>\n            <td>Operator</td>\n            <td class="lims_ophys_session_operator">sams</td>\n        </tr>\n        \n        <tr>\n            <td>Mouse ID</td>\n            <td class="lims_ophys_session_external_specimen_name">429956</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t</div>\n</div>\n    </div>\n\n    <div>\n        <div class="panel-group">\n\t<div class="panel panel-default">\n\t\t<div class="panel-heading">LIMS:  Ophys Experiment\n\t\t\t<span class="pull-right clickable"><i class="glyphicon glyphicon-chevron-up"></i></span>\n\t\t</div>\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545454</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class="lims_ophys_experiment_depth">211</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545456</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class="lims_ophys_experiment_depth">150</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545458</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class ...
#   {'submit_datetime': datetime.datetime(2019, 7, 3, 14, 57, 39, 898000),
#    'qc_reviewer': 'sams',
#    'qc_report_html': '<div class="qc_report_page">\n\n    <div>\n        <div class="panel-group">\n\t<div class="panel panel-default">\n\t\t<div class="panel-heading">LIMS:  Ophys Session\n\t\t\t<span class="pull-right clickable"><i class="glyphicon glyphicon-chevron-up"></i></span>\n\t\t</div>\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_session_id">842023261</td>\n        </tr>\n        \n        <tr>\n            <td>Name</td>\n            <td class="lims_ophys_session_name">20190327_429956_Ophys1</td>\n        </tr>\n        \n        <tr>\n            <td>Workflow State</td>\n            <td class="lims_ophys_session_workflow_state">uploaded</td>\n        </tr>\n        \n        <tr>\n            <td>Rig</td>\n            <td class="lims_ophys_session_rig">MESO.1</td>\n        </tr>\n        \n        <tr>\n            <td>Operator</td>\n            <td class="lims_ophys_session_operator">sams</td>\n        </tr>\n        \n        <tr>\n            <td>Mouse ID</td>\n            <td class="lims_ophys_session_external_specimen_name">429956</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t</div>\n</div>\n    </div>\n\n    <div>\n        <div class="panel-group">\n\t<div class="panel panel-default">\n\t\t<div class="panel-heading">LIMS:  Ophys Experiment\n\t\t\t<span class="pull-right clickable"><i class="glyphicon glyphicon-chevron-up"></i></span>\n\t\t</div>\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545454</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class="lims_ophys_experiment_depth">211</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545456</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class="lims_ophys_experiment_depth">150</td>\n        </tr>\n        \n    </tbody>\n</table>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t<div class="panel-body table-responsive">\n\t\t\t\t\t\t\t\t<!-- A simple key-value table -->\n<table class="table table-bordered table-hover table-responsive valign" style="table-layout:fixed" id="metric_table">\n    <tbody>\n        \n        <tr>\n            <td>LIMS ID</td>\n            <td class="lims_ophys_experiment_id">842545458</td>\n        </tr>\n        \n        <tr>\n            <td>Area</td>\n            <td class="lims_ophys_experiment_area">VISp</td>\n        </tr>\n        \n        <tr>\n            <td>Depth</td>\n            <td class ...
