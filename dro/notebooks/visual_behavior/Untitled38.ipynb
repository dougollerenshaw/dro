# %%
from visual_behavior_glm.glm import GLM
from visual_behavior.data_access import loading
import visual_behavior_glm.GLM_fit_tools as gft
import visual_behavior_glm.GLM_analysis_tools as gat

# %%
oeid = 1000744370
glm = GLM(
    ophys_experiment_id = oeid, 
    version='11a_L2_optimize_by_session', 
    use_previous_fit=True, 
    log_results=False, 
    log_weights=False
)
# Out:
# importing GLM_fit_tools from /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_11a_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py
# loading previous fit...
# loading data for 1000744370_485152_200115_VISp_0_Slc17a7-IRES2-Cre_MESO.1_behavior_248
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/behavior/running_processing.py:367: UserWarning: Time array is 1 value shorter than encoder array. Last encoder value removed
#
#   "value removed\n", UserWarning, stacklevel=1)
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/behavior/running_processing.py:15: RuntimeWarning: Mean of empty slice
#   dxdt = np.nanmean(dxdt, axis=0)
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:BehaviorProjectLimsApi:Getting all ophys sessions. This might take a while.
#     Adding kernel: intercept
#     Adding kernel: time
#     Adding kernel: licks
# Error encountered while adding kernel for licks. Attemping to continue without this kernel.
# Less than minimum number of events: 1 licks
#     Adding kernel: hits
# Error encountered while adding kernel for hits. Attemping to continue without this kernel.
# Trial type regressors arent defined for passive sessions (sessions with less than 5 rewards)
#     Adding kernel: misses
# Error encountered while adding kernel for misses. Attemping to continue without this kernel.
# Trial type regressors arent defined for passive sessions (sessions with less than 5 rewards)
#     Adding kernel: passive_change
#     Adding kernel: false_alarms
# Error encountered while adding kernel for false_alarms. Attemping to continue without this kernel.
# Trial type regressors arent defined for passive sessions (sessions with less than 5 rewards)
#     Adding kernel: correct_rejects
# Error encountered while adding kernel for correct_rejects. Attemping to continue without this kernel.
# Trial type regressors arent defined for passive sessions (sessions with less than 5 rewards)
#     Adding kernel: omissions
#     Adding kernel: running
#                  : Normalized by max value: 100
#     Adding kernel: pupil
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_11a_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py:762: RuntimeWarning: invalid value encountered in greater
#   d_mask = np.abs(np.diff(x,append=x[-1])) > run_params['eye_transient_threshold']
# /home/dougo/.local/lib/python3.7/site-packages/scipy/interpolate/interpolate.py:684: RuntimeWarning: invalid value encountered in greater
#   above_bounds = x_new > self.x[-1]
#                  : Mean Centering
#                  : Standardized to unit variance
#     Adding kernel: face_motion_PC_0
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# Error encountered while adding kernel for face_motion_PC_0. Attemping to continue without this kernel.
# get_ophys_session_id_from_ophys_experiment_id() takes 1 positional argument but 2 were given
#     Adding kernel: face_motion_PC_1
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# Error encountered while adding kernel for face_motion_PC_1. Attemping to continue without this kernel.
# get_ophys_session_id_from_ophys_experiment_id() takes 1 positional argument but 2 were given
#     Adding kernel: face_motion_PC_2
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# Error encountered while adding kernel for face_motion_PC_2. Attemping to continue without this kernel.
# get_ophys_session_id_from_ophys_experiment_id() takes 1 positional argument but 2 were given
#     Adding kernel: face_motion_PC_3
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# Error encountered while adding kernel for face_motion_PC_3. Attemping to continue without this kernel.
# get_ophys_session_id_from_ophys_experiment_id() takes 1 positional argument but 2 were given
#     Adding kernel: face_motion_PC_4
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# Error encountered while adding kernel for face_motion_PC_4. Attemping to continue without this kernel.
# get_ophys_session_id_from_ophys_experiment_id() takes 1 positional argument but 2 were given
#     Adding kernel: image0
#     Adding kernel: image1
#     Adding kernel: image2
#     Adding kernel: image3
#     Adding kernel: image4
#     Adding kernel: image5
#     Adding kernel: image6
#     Adding kernel: image7
#     Adding kernel: model_bias
# Error encountered while adding kernel for model_bias. Attemping to continue without this kernel.
# [Errno 2] File b'/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/1000462035.csv' does not exist: b'/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/1000462035.csv'
#     Adding kernel: model_task0
# Error encountered while adding kernel for model_task0. Attemping to continue without this kernel.
# [Errno 2] File b'/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/1000462035.csv' does not exist: b'/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/1000462035.csv'
#     Adding kernel: model_omissions1
# Error encountered while adding kernel for model_omissions1. Attemping to continue without this kernel.
# [Errno 2] File b'/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/1000462035.csv' does not exist: b'/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/1000462035.csv'
#     Adding kernel: model_timing1D
# Error encountered while adding kernel for model_timing1D. Attemping to continue without this kernel.
# [Errno 2] File b'/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/1000462035.csv' does not exist: b'/allen/programs/braintv/workgroups/nc-ophys/alex.piet/behavior/model_output/1000462035.csv'
# The following kernels failed to be added to the model:
# {'face_motion_PC_3', 'model_timing1D', 'face_motion_PC_0', 'misses', 'face_motion_PC_1', 'face_motion_PC_2', 'model_bias', 'model_task0', 'licks', 'model_omissions1', 'hits', 'correct_rejects', 'face_motion_PC_4', 'false_alarms'}
# The following dropouts failed to be added to the model:
# {'single-false_alarms', 'single-model_omissions1', 'single-misses', 'single-model_timing1D', 'single-licks', 'single-beh_model', 'single-face_motion_PC_2', 'beh_model', 'single-face_motion_PC_1', 'single-face_motion_PC_0', 'single-face_motion_PC_4', 'single-face_motion_PC_3', 'single-model_task0', 'licking', 'single-licking', 'single-face_motion_energy', 'single-hits', 'face_motion_energy', 'single-model_bias', 'single-correct_rejects'}
# done loading previous fit
# done fitting model, collecting results
# done collecting results
# done building GLM object

# %%
glm.X
# Out:
# <xarray.DataArray (timestamps: 38544, weights: 204)>
# array([[1.00000000e+00, 2.59443753e-05, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 5.18887505e-05, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 7.78331258e-05, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [1.00000000e+00, 9.99948111e-01, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 9.99974056e-01, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])
# Coordinates:
#   * weights     (weights) <U18 'intercept_0' 'time_0' ... 'image7_4' 'image7_5'
#   * timestamps  (timestamps) float64 308.8 308.8 308.9 ... 3.914e+03 3.914e+03

# %%
session = gft.load_data(oeid)
run_params = glm.run_params
fit = gat.load_fit_pkl(run_params, oeid)
# Out:
# loading data for 1000744370_485152_200115_VISp_0_Slc17a7-IRES2-Cre_MESO.1_behavior_248
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/behavior/running_processing.py:367: UserWarning: Time array is 1 value shorter than encoder array. Last encoder value removed
#
#   "value removed\n", UserWarning, stacklevel=1)
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/behavior/running_processing.py:15: RuntimeWarning: Mean of empty slice
#   dxdt = np.nanmean(dxdt, axis=0)
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:BehaviorProjectLimsApi:Getting all ophys sessions. This might take a while.

# %%
from importlib import reload
reload(gft)
gft.process_eye_data(session,run_params,ophys_timestamps =fit['fit_trace_timestamps'] )
# Out:
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
#                  : Mean Centering
#                  : Standardized to unit variance
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/visual_behavior_glm/visual_behavior_glm/GLM_fit_tools.py:758: RuntimeWarning: invalid value encountered in greater
#   d_mask = np.abs(np.diff(x,append=x[-1])) > run_params['eye_transient_threshold']
# /home/dougo/.local/lib/python3.7/site-packages/scipy/interpolate/interpolate.py:684: RuntimeWarning: invalid value encountered in greater
#   above_bounds = x_new > self.x[-1]
#        timestamps     cr_area      eye_area    pupil_area  likely_blink  \
# 0       308.75146  243.059462  48764.974209   6975.034060           0.0
# 1       308.84501  254.758274  49372.070049   6899.113785           0.0
# 2       308.93855  218.401221  51084.295973   6958.209980           0.0
# 3       309.03210  188.415000  50765.448066   7167.694957           0.0
# 4       309.12565  194.814515  51186.505495   7346.793904           0.0
# ...           ...         ...           ...           ...           ...
# 38539  3914.05606  219.697834  65166.667994  12098.102086           0.0
# 38540  3914.14961  215.873915  64931.264966  11605.152456           0.0
# 38541  3914.24316  208.907385  64969.327983  11408.460280           0.0
# 38542  3914.33671  206.276118  65077.934672  11113.542464           0.0
# 38543  3914.43026  188.623171  65124.336627  10999.973492           0.0
#
#        cr_center_x  cr_center_y  cr_width  cr_height    cr_phi  ...  \
# 0       290.501775   278.276553  9.724424   7.950517  0.054245  ...
# 1       290.921584   277.969074  9.657084   8.387023  0.151177  ...
# 2       290.174205   277.980779  8.909865   7.802469 -0.086511  ...
# 3       291.388654   277.484978  8.252144   7.264869  0.142030  ...
# 4       291.098702   278.185929  8.549802   7.254004 -0.045840  ...
# ...            ...          ...       ...        ...       ...  ...
# 38539   291.310714   271.186568  7.381448   9.470729 -0.183068  ...
# 38540   292.445375   268.961420  7.489347   9.174827 -0.140906  ...
# 38541   291.260691   269.275436  7.300505   9.108259 -0.074769  ...
# 38542   290.454257   269.818130  7.076030   9.279194 -0.145524  ...
# 38543   290.575208   269.509104  6.700422   8.961787 -0.084299  ...
#
#        eye_width_zscore  eye_height   eye_phi  pupil_center_x  pupil_center_y  \
# 0             -2.009342  103.482314 -0.082187      334.411286      247.541169
# 1             -1.994850  104.732368 -0.089534      333.657189      247.214973
# 2             -1.102088  106.199112 -0.110985      331.329656      247.243139
# 3             -1.296935  105.999013 -0.090224      333.016931      245.626281
# 4             -1.266792  106.805856 -0.095455      333.497630      245.488210
# ...                 ...         ...       ...             ...             ...
# 38539          0.958563  129.495374 -0.140931      325.493091      241.978701
# 38540          0.758513  129.583056 -0.104962      327.250235      241.273680
# 38541          0.914282  129.225793 -0.116148      325.650706      241.735548
# 38542          0.646432  130.189405 -0.115124      326.945183      241.305714
# 38543          0.766370  129.946325 -0.126471      325.497107      241.994917
#
#        pupil_width  pupil_height  pupil_phi  pupil_radius  pupil_radius_zscore
# 0        47.118582     42.981784   0.494800     47.118582            -0.469558
# 1        46.861780     41.527478   0.416989     46.861780            -0.506071
# 2        47.061978     41.860411   0.402305     47.061978            -0.477606
# 3        47.765290     42.688322   0.469693     47.765290            -0.377606
# 4        48.357586     42.868254   0.491449     48.357586            -0.293392
# ...            ...           ...        ...           ...                  ...
# 38539    62.055974     53.790492   0.627516     62.055974             1.654294
# 38540    60.778434     54.114675   0.558122     60.778434             1.472649
# 38541    60.259807     53.275313   0.617238     60.259807             1.398909
# 38542    59.476774     51.765693   0.537937     59.476774             1.287575
# 38543    59.171395     52.337061   0.557217     59.171395             1.244155
#
# [38544 rows x 23 columns]

# %%
session.cell_
# Out:
# > /allen/programs/braintv/workgroups/nc-ophys/Doug/code/dro/dro/notebooks/visual_behavior/pandas/_libs/hashtable_class_helper.pxi(1614)pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ipdb> u
# > /allen/programs/braintv/workgroups/nc-ophys/Doug/code/dro/dro/notebooks/visual_behavior/pandas/_libs/hashtable_class_helper.pxi(1607)pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ipdb> u
# > /allen/programs/braintv/workgroups/nc-ophys/Doug/code/dro/dro/notebooks/visual_behavior/pandas/_libs/index.pyx(131)pandas._libs.index.IndexEngine.get_loc()
#
# ipdb> u
# > /allen/programs/braintv/workgroups/nc-ophys/Doug/code/dro/dro/notebooks/visual_behavior/pandas/_libs/index.pyx(107)pandas._libs.index.IndexEngine.get_loc()
#
# ipdb> u
# > /home/dougo/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py(2899)get_loc()
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# ipdb> u
# > /home/dougo/.local/lib/python3.7/site-packages/pandas/core/frame.py(2995)__getitem__()
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ipdb> u
# > /allen/programs/braintv/workgroups/nc-ophys/Doug/code/visual_behavior_glm/visual_behavior_glm/GLM_fit_tools.py(767)process_eye_data()
#     765     for column in eye.keys():
#     766         if column != 'time':
# --> 767             f = scipy.interpolate.interp1d(eye['time'], eye[column], bounds_error=False)
#     768             ophys_eye[column] = f(ophys_eye['timestamps'])
#     769             ophys_eye[column].fillna(method='ffill',inplace=True)
#
# ipdb> eye
#         timestamps     cr_area      eye_area    pupil_area  likely_blink  \
# frame
# 0              NaN         NaN           NaN           NaN           NaN
# 1              NaN         NaN           NaN           NaN           NaN
# 2              NaN         NaN           NaN           NaN           NaN
# 3              NaN         NaN           NaN           NaN           NaN
# 4              NaN         NaN           NaN           NaN           NaN
# ...            ...         ...           ...           ...           ...
# 136455  4548.66047  205.616667  51671.739131  10154.159563           0.0
# 136456  4548.69344  202.582693  51887.229620  10316.538068           0.0
# 136457  4548.71380  208.112506  51788.859802  10478.020996           0.0
# 136458  4548.74731  195.262872  52395.998065  10419.455144           0.0
# 136459  4548.78908  191.339470  53280.654085  10288.269841           0.0
#
#         cr_center_x  cr_center_y  cr_width  cr_height    cr_phi  ...  \
# frame                                                            ...
# 0               NaN          NaN       NaN        NaN       NaN  ...
# 1               NaN          NaN       NaN        NaN       NaN  ...
# 2               NaN          NaN       NaN        NaN       NaN  ...
# 3               NaN          NaN       NaN        NaN       NaN  ...
# 4               NaN          NaN       NaN        NaN       NaN  ...
# ...             ...          ...       ...        ...       ...  ...
# 136455   298.480625   262.220121  8.398335   7.793190 -0.679588  ...
# 136456   298.154834   262.901275  8.399555   7.677082 -0.682971  ...
# 136457   298.149131   263.143269  8.403745   7.882708 -0.612836  ...
# 136458   298.826081   261.207026  8.268564   7.516916 -0.586481  ...
# 136459   301.033234   256.220449  6.792277   8.966838  0.505414  ...
#
#         eye_center_y   eye_width  eye_height   eye_phi  pupil_center_x  \
# frame
# 0                NaN         NaN         NaN       NaN             NaN
# 1                NaN         NaN         NaN       NaN             NaN
# 2                NaN         NaN         NaN       NaN             NaN
# 3                NaN         NaN         NaN       NaN             NaN
# 4                NaN         NaN         NaN       NaN             NaN
# ...              ...         ...         ...       ...             ...
# 136455    245.866035  153.191691  107.366302 -0.057231      331.176467
# 136456    246.995745  152.600000  108.232098 -0.064380      330.224902
# 136457    247.329657  152.504439  108.094599 -0.062782      330.808698
# 136458    245.602798  153.295906  108.797192 -0.042843      330.492204
# 136459    242.133546  153.798401  110.272661 -0.043067      332.428623
#
#         pupil_center_y  pupil_width  pupil_height  pupil_phi  pupil_radius
# frame
# 0                  NaN          NaN           NaN        NaN           NaN
# 1                  NaN          NaN           NaN        NaN           NaN
# 2                  NaN          NaN           NaN        NaN           NaN
# 3                  NaN          NaN           NaN        NaN           NaN
# 4                  NaN          NaN           NaN        NaN           NaN
# ...                ...          ...           ...        ...           ...
# 136455      229.493523    56.852171     48.970391   0.385726     56.852171
# 136456      230.359125    57.304939     49.483928   0.311680     57.304939
# 136457      230.184504    57.751690     49.520654   0.374968     57.751690
# 136458      228.519993    57.590065     48.878855   0.392418     57.590065
# 136459      225.254008    57.226375     49.429805   0.304320     57.226375
#
# [136460 rows x 21 columns]
# ipdb> q
