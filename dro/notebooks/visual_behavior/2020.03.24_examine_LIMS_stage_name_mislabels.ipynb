# %%
import pandas as pd

# %widescreen
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # read in CSV file containing sessions with stage name mismatch

# %%
filename = '/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/stage_name_mismatches_03.24.2020.csv'
experiments_with_naming_issues = pd.read_csv(filename)

# %% [markdown]
# # display limited columns (more columns exist, see the CSV file for all)

# %%
cols_to_show = [
    'ophys_experiment_id',
    'ophys_session_id',
    'container_id',
    'project_code',
    'container_workflow_state',
    'experiment_workflow_state',
    'session_name',
    'session_type',
    'pkl_stage_name',
    'lims_stage_name',
    'problem_type',
    'desired_LIMS_stage_name',
]

# %%
experiments_with_naming_issues[cols_to_show]
# Out:
#     ophys_experiment_id  ophys_session_id  container_id          project_code  \
# 0             868245889         867455174     898954413        VisualBehavior
# 1             872434950         871522846     898954413        VisualBehavior
# 2             797257159         796608428     791352433        VisualBehavior
# 3             834279512         833705055     825183217        VisualBehavior
# 4             885061426         884352232     876693090        VisualBehavior
# 5             881881193         881236651     869781307        VisualBehavior
# 6             872432459         871534712     863992815        VisualBehavior
# 7             894725344         894247390     902748564        VisualBehavior
# 8             897374358         896264501     902748564        VisualBehavior
# 9             899082454         898944825     902748564        VisualBehavior
# 10            800034837         798782540     800219216        VisualBehavior
# 11            800034812         799931731     800219216        VisualBehavior
# 12            798598354         793204176     814797471        VisualBehavior
# 13            856095742         855753717     848390542        VisualBehavior
# 14            791450782         791121085     814796698        VisualBehavior
# 15            794380439         794238479     814796698        VisualBehavior
# 16            795954023         795733616     814796698        VisualBehavior
# 17            796304798         796252697     814796698        VisualBehavior
# 18            798400822         797639620     814796698        VisualBehavior
# 19            799357437         799024324     814796698        VisualBehavior
# 20            910199584         909228684     895259658  VisualBehaviorTask1B
# 21            972666750         972022565     966316564  VisualBehaviorTask1B
# 22            838849908         838101551     831881466        VisualBehavior
# 23            853965797         853744857     845588020        VisualBehavior
# 24            862016695         861710170     845588020        VisualBehavior
# 25            864936381         864811045     845588020        VisualBehavior
# 26            865744231         865051382     845588020        VisualBehavior
# 27            790146945         789746168     782536745        VisualBehavior
# 28            794382032         793870077     782536745        VisualBehavior
# 29            895421128         894975064     902748650        VisualBehavior
# 30            914062473         913565955     904629174  VisualBehaviorTask1B
# 31            901557228         898849158     890047007        VisualBehavior
# 32            827236451         826659883     819121139        VisualBehavior
# 33            830697288         830149825     819121139        VisualBehavior
# 34            895418485         894835974     890047007        VisualBehavior
# 35            903400112         902617173     890047007        VisualBehavior
# 36            810736340         810203324     803516615        VisualBehavior
# 37            811456547         811071835     803516615        VisualBehavior
# 38            827236946         826655164     803516615        VisualBehavior
# 39            810120743         809600993     803517529        VisualBehavior
# 40            821011078         820871900     812858755        VisualBehavior
# 41            824333792         823931897     812858755        VisualBehavior
# 42            848007790         847494416     876693136        VisualBehavior
# 43           1005123562        1004988945    1000740435  VisualBehaviorTask1B
# 44            853328133         853141772     846213087        VisualBehavior
# 45            820307042         819721037     812858718        VisualBehavior
# 46            849204593         848889656     843049827        VisualBehavior
# 47            844394546         844073954     838105949        VisualBehavior
# 48            848694025         848087345     838105949        VisualBehavior
# 49            836912930         836322466     829561794        VisualBehavior
# 50            837297990         837083549     830457573        VisualBehavior
# 51            974948847         974659900     968890932        VisualBehavior
# 52            894724592         893951816     876461613        VisualBehavior
# 53            796306435         796202631     814796612        VisualBehavior
# 54            911644701         911457686     896318095  VisualBehaviorTask1B
# 55            912717370         912232900     896318095  VisualBehaviorTask1B
# 56            809191721         808676476     814797528        VisualBehavior
# 57            810119680         809658968     803589437        VisualBehavior
# 58            791453299         791355484     814796558        VisualBehavior
# 59            854703904         854090022     846215539        VisualBehavior
# 60            906877227         906303646     895259496  VisualBehaviorTask1B
#
#    container_workflow_state experiment_workflow_state  \
# 0                    failed                    failed
# 1                    failed                    failed
# 2              container_qc                    passed
# 3              container_qc                    passed
# 4              container_qc                    passed
# 5              container_qc                    passed
# 6              container_qc                    passed
# 7              container_qc                    failed
# 8              container_qc                    failed
# 9              container_qc                    passed
# 10                   failed                    failed
# 11                   failed                    failed
# 12                   failed                    failed
# 13             container_qc                    passed
# 14                   failed                    failed
# 15                   failed                    failed
# 16                   failed                    failed
# 17                   failed                    failed
# 18                   failed                    failed
# 19                   failed                    failed
# 20                   failed                    passed
# 21                   failed                   created
# 22                   failed                    passed
# 23             container_qc                    failed
# 24             container_qc                    failed
# 25             container_qc                    failed
# 26             container_qc                    passed
# 27             container_qc                    passed
# 28             container_qc                    failed
# 29             container_qc                    passed
# 30                   failed                    passed
# 31             container_qc                        qc
# 32                   failed                    failed
# 33                   failed                    passed
# 34             container_qc                    failed
# 35             container_qc                    passed
# 36             container_qc                    failed
# 37             container_qc                    failed
# 38             container_qc                    passed
# 39             container_qc                    passed
# 40             container_qc                    passed
# 41             container_qc                    failed
# 42             container_qc                    passed
# 43                   failed                        qc
# 44             container_qc                    passed
# 45                   failed                    passed
# 46             container_qc                    passed
# 47                   failed                    failed
# 48                   failed                    passed
# 49             container_qc                    passed
# 50                   failed                    passed
# 51                   failed                    failed
# 52             container_qc                    passed
# 53             container_qc                    passed
# 54             container_qc                    failed
# 55             container_qc                    failed
# 56             container_qc                    passed
# 57             container_qc                    passed
# 58             container_qc                    passed
# 59             container_qc                    passed
# 60             container_qc                    passed
#
#                       session_name                 session_type  \
# 0              20190514_448897_7RF                          NaN
# 1          20190520_448897_7RF_Map                          NaN
# 2         20181217_412036_7_RF_map              full_field_test
# 3              20190307_429952_7RF  VisCodingTargetedMovieClips
# 4          20190611_449441_7RF_Map  VisCodingTargetedMovieClips
# 5              20190605_450471_7RF  VisCodingTargetedMovieClips
# 6              20190520_448900_7RF  VisCodingTargetedMovieClips
# 7              20190625_456564_7RF                          NaN
# 8              20190628_456564_7RF                          NaN
# 9              20190702_456564_7RF  VisCodingTargetedMovieClips
# 10      20181219_408224_6_images_B             OPHYS_6_images_B
# 11             20181220_408224_7RF              full_field_test
# 12             20181211_409258_7RF  VisCodingTargetedMovieClips
# 13             20190423_447663_7RF  VisCodingTargetedMovieClips
# 14      20181206_412364_7RFMapping  VisCodingTargetedMovieClips
# 15             20181212_412364_7RF  VisCodingTargetedMovieClips
# 16             20181214_412364_7RF  VisCodingTargetedMovieClips
# 17             20181216_412364_7RF  VisCodingTargetedMovieClips
# 18             20181218_412364_7RF  VisCodingTargetedMovieClips
# 19            20181219_412364_7_RF  VisCodingTargetedMovieClips
# 20         20190719_460746_7RF_map                          NaN
# 21       20191023_479835_session1b                          NaN
# 22             20190318_432375_7RF  VisCodingTargetedMovieClips
# 23             20190417_445270_7RF                          NaN
# 24             20190502_445270_7RF                          NaN
# 25             20190508_445270_7RF                          NaN
# 26             20190509_445270_7RF  VisCodingTargetedMovieClips
# 27             20181203_403491_7RF  VisCodingTargetedMovieClips
# 28             20181212_403491_7RF  VisCodingTargetedMovieClips
# 29             20190626_456917_7RF  VisCodingTargetedMovieClips
# 30     20190729_462887_7RF_passive                          NaN
# 31  20190702_456916_7RF_MAP_retake                          NaN
# 32             20190221_431246_7RF  VisCodingTargetedMovieClips
# 33             20190228_431246_7RF  VisCodingTargetedMovieClips
# 34         20190626_456916_7RF_Map                          NaN
# 35  20190710_456916_7RF_Map_retake  VisCodingTargetedMovieClips
# 36             20190118_423606_7RF  VisCodingTargetedMovieClips
# 37             20190121_423606_7RF  VisCodingTargetedMovieClips
# 38             20190221_423606_7RF  VisCodingTargetedMovieClips
# 39             20190117_425493_7RF  VisCodingTargetedMovieClips
# 40    20190208_431023_VISp_175um_7  VisCodingTargetedMovieClips
# 41  20190128_431018_VISp_175um_7rf  VisCodingTargetedMovieClips
# 42             20190408_442709_7RF  VisCodingTargetedMovieClips
# 43        486738_20200204_4imagesA             OPHYS_3_images_B
# 44             20194017_436662_7RF  VisCodingTargetedMovieClips
# 45  20190207_431018_VISp_175um_7rf  VisCodingTargetedMovieClips
# 46             20190410_440298_7RF  VisCodingTargetedMovieClips
# 47             20190401_435838_7RF                          NaN
# 48             20190409_435838_7RF  VisCodingTargetedMovieClips
# 49             20190313_431252_7RF  VisCodingTargetedMovieClips
# 50             20190314_433245_7RF  VisCodingTargetedMovieClips
# 51        20191031_483803_3imagesA             OPHYS_1_images_A
# 52      20190625_453913_7RFmapping  VisCodingTargetedMovieClips
# 53             20181216_412366_7RF  VisCodingTargetedMovieClips
# 54             20190724_462468_7RF                          NaN
# 55             20190725_462468_7RF                          NaN
# 56       20190115_421136_7imagesRF  VisCodingTargetedMovieClips
# 57             20190117_425496_7RF  VisCodingTargetedMovieClips
# 58  20181206_416369_2P3_VISp_375_7  VisCodingTargetedMovieClips
# 59             20190419_445002_7RF  VisCodingTargetedMovieClips
# 60          20190715_461946_7RFmap              full_field_test
#
#               pkl_stage_name              lims_stage_name  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN              full_field_test
# 3                        NaN  VisCodingTargetedMovieClips
# 4                        NaN  VisCodingTargetedMovieClips
# 5                        NaN  VisCodingTargetedMovieClips
# 6                        NaN  VisCodingTargetedMovieClips
# 7                        NaN                          NaN
# 8                        NaN                          NaN
# 9                        NaN  VisCodingTargetedMovieClips
# 10  OPHYS_2_images_A_passive             OPHYS_6_images_B
# 11                       NaN              full_field_test
# 12                       NaN  VisCodingTargetedMovieClips
# 13                       NaN  VisCodingTargetedMovieClips
# 14                       NaN  VisCodingTargetedMovieClips
# 15                       NaN  VisCodingTargetedMovieClips
# 16                       NaN  VisCodingTargetedMovieClips
# 17                       NaN  VisCodingTargetedMovieClips
# 18                       NaN  VisCodingTargetedMovieClips
# 19                       NaN  VisCodingTargetedMovieClips
# 20                       NaN                          NaN
# 21          OPHYS_1_images_B                          NaN
# 22                       NaN  VisCodingTargetedMovieClips
# 23                       NaN                          NaN
# 24                       NaN                          NaN
# 25                       NaN                          NaN
# 26                       NaN  VisCodingTargetedMovieClips
# 27                       NaN  VisCodingTargetedMovieClips
# 28                       NaN  VisCodingTargetedMovieClips
# 29                       NaN  VisCodingTargetedMovieClips
# 30                       NaN                          NaN
# 31          OPHYS_3_images_E                          NaN
# 32                       NaN  VisCodingTargetedMovieClips
# 33                       NaN  VisCodingTargetedMovieClips
# 34                       NaN                          NaN
# 35                       NaN  VisCodingTargetedMovieClips
# 36                       NaN  VisCodingTargetedMovieClips
# 37                       NaN  VisCodingTargetedMovieClips
# 38                       NaN  VisCodingTargetedMovieClips
# 39                       NaN  VisCodingTargetedMovieClips
# 40                       NaN  VisCodingTargetedMovieClips
# 41                       NaN  VisCodingTargetedMovieClips
# 42                       NaN  VisCodingTargetedMovieClips
# 43          OPHYS_4_images_A             OPHYS_3_images_B
# 44                       NaN  VisCodingTargetedMovieClips
# 45                       NaN  VisCodingTargetedMovieClips
# 46                       NaN  VisCodingTargetedMovieClips
# 47                       NaN                          NaN
# 48                       NaN  VisCodingTargetedMovieClips
# 49                       NaN  VisCodingTargetedMovieClips
# 50                       NaN  VisCodingTargetedMovieClips
# 51          OPHYS_3_images_A             OPHYS_1_images_A
# 52                       NaN  VisCodingTargetedMovieClips
# 53                       NaN  VisCodingTargetedMovieClips
# 54                       NaN                          NaN
# 55                       NaN                          NaN
# 56                       NaN  VisCodingTargetedMovieClips
# 57                       NaN  VisCodingTargetedMovieClips
# 58                       NaN  VisCodingTargetedMovieClips
# 59                       NaN  VisCodingTargetedMovieClips
# 60                       NaN              full_field_test
#
#                       problem_type          desired_LIMS_stage_name
# 0     rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 1     rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 2   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 3   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 4   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 5   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 6   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 7     rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 8     rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 9   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 10                    pkl_mismatch         OPHYS_2_images_A_passive
# 11  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 12  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 13  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 14  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 15  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 16  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 17  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 18  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 19  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 20    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 21                    pkl_mismatch                 OPHYS_1_images_B
# 22  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 23    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 24    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 25    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 26  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 27  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 28  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 29  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 30    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 31                    pkl_mismatch                 OPHYS_3_images_E
# 32  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 33  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 34    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 35  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 36  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 37  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 38  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 39  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 40  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 41  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 42  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 43                    pkl_mismatch                 OPHYS_4_images_A
# 44  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 45  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 46  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 47    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 48  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 49  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 50  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 51                    pkl_mismatch                 OPHYS_3_images_A
# 52  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 53  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 54    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 55    rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 56  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 57  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 58  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 59  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 60  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping

# %% [markdown]
# # look at two problem types individually

# %% [markdown]
# ## There are three types of problems that I identified, labeled as follows in the 'problem_type' column:
# 1. 'rf_mapping_incorrect_lims_name': these are sessions that are labeled as either `VisCodingTargetedMovieClips` or `full_field_test`, but appear to be regular `OPHYS_7_receptive_field_mapping` sessions. They should be renamed `OPHYS_7_receptive_field_mapping`.
# 2. 'rf_mapping_missing_lims_name': these are sessions that appear to be RF mapping sessions based on the session name, but for which there is not a matching 'session_type' in LIMS
# 3. 'pkl_mismatch': these are sessions where the LIMS stage name does not match the stage name stored in the PKL file. I'm making the assumption that the PKL file is correct and that the LIMS stage name is incorrect.

# %%
experiments_with_naming_issues.query("problem_type == 'rf_mapping_incorrect_lims_name'")[cols_to_show]
# Out:
#     ophys_experiment_id  ophys_session_id  container_id          project_code  \
# 2             797257159         796608428     791352433        VisualBehavior
# 3             834279512         833705055     825183217        VisualBehavior
# 4             885061426         884352232     876693090        VisualBehavior
# 5             881881193         881236651     869781307        VisualBehavior
# 6             872432459         871534712     863992815        VisualBehavior
# 9             899082454         898944825     902748564        VisualBehavior
# 11            800034812         799931731     800219216        VisualBehavior
# 12            798598354         793204176     814797471        VisualBehavior
# 13            856095742         855753717     848390542        VisualBehavior
# 14            791450782         791121085     814796698        VisualBehavior
# 15            794380439         794238479     814796698        VisualBehavior
# 16            795954023         795733616     814796698        VisualBehavior
# 17            796304798         796252697     814796698        VisualBehavior
# 18            798400822         797639620     814796698        VisualBehavior
# 19            799357437         799024324     814796698        VisualBehavior
# 22            838849908         838101551     831881466        VisualBehavior
# 26            865744231         865051382     845588020        VisualBehavior
# 27            790146945         789746168     782536745        VisualBehavior
# 28            794382032         793870077     782536745        VisualBehavior
# 29            895421128         894975064     902748650        VisualBehavior
# 32            827236451         826659883     819121139        VisualBehavior
# 33            830697288         830149825     819121139        VisualBehavior
# 35            903400112         902617173     890047007        VisualBehavior
# 36            810736340         810203324     803516615        VisualBehavior
# 37            811456547         811071835     803516615        VisualBehavior
# 38            827236946         826655164     803516615        VisualBehavior
# 39            810120743         809600993     803517529        VisualBehavior
# 40            821011078         820871900     812858755        VisualBehavior
# 41            824333792         823931897     812858755        VisualBehavior
# 42            848007790         847494416     876693136        VisualBehavior
# 44            853328133         853141772     846213087        VisualBehavior
# 45            820307042         819721037     812858718        VisualBehavior
# 46            849204593         848889656     843049827        VisualBehavior
# 48            848694025         848087345     838105949        VisualBehavior
# 49            836912930         836322466     829561794        VisualBehavior
# 50            837297990         837083549     830457573        VisualBehavior
# 52            894724592         893951816     876461613        VisualBehavior
# 53            796306435         796202631     814796612        VisualBehavior
# 56            809191721         808676476     814797528        VisualBehavior
# 57            810119680         809658968     803589437        VisualBehavior
# 58            791453299         791355484     814796558        VisualBehavior
# 59            854703904         854090022     846215539        VisualBehavior
# 60            906877227         906303646     895259496  VisualBehaviorTask1B
#
#    container_workflow_state experiment_workflow_state  \
# 2              container_qc                    passed
# 3              container_qc                    passed
# 4              container_qc                    passed
# 5              container_qc                    passed
# 6              container_qc                    passed
# 9              container_qc                    passed
# 11                   failed                    failed
# 12                   failed                    failed
# 13             container_qc                    passed
# 14                   failed                    failed
# 15                   failed                    failed
# 16                   failed                    failed
# 17                   failed                    failed
# 18                   failed                    failed
# 19                   failed                    failed
# 22                   failed                    passed
# 26             container_qc                    passed
# 27             container_qc                    passed
# 28             container_qc                    failed
# 29             container_qc                    passed
# 32                   failed                    failed
# 33                   failed                    passed
# 35             container_qc                    passed
# 36             container_qc                    failed
# 37             container_qc                    failed
# 38             container_qc                    passed
# 39             container_qc                    passed
# 40             container_qc                    passed
# 41             container_qc                    failed
# 42             container_qc                    passed
# 44             container_qc                    passed
# 45                   failed                    passed
# 46             container_qc                    passed
# 48                   failed                    passed
# 49             container_qc                    passed
# 50                   failed                    passed
# 52             container_qc                    passed
# 53             container_qc                    passed
# 56             container_qc                    passed
# 57             container_qc                    passed
# 58             container_qc                    passed
# 59             container_qc                    passed
# 60             container_qc                    passed
#
#                       session_name                 session_type  \
# 2         20181217_412036_7_RF_map              full_field_test
# 3              20190307_429952_7RF  VisCodingTargetedMovieClips
# 4          20190611_449441_7RF_Map  VisCodingTargetedMovieClips
# 5              20190605_450471_7RF  VisCodingTargetedMovieClips
# 6              20190520_448900_7RF  VisCodingTargetedMovieClips
# 9              20190702_456564_7RF  VisCodingTargetedMovieClips
# 11             20181220_408224_7RF              full_field_test
# 12             20181211_409258_7RF  VisCodingTargetedMovieClips
# 13             20190423_447663_7RF  VisCodingTargetedMovieClips
# 14      20181206_412364_7RFMapping  VisCodingTargetedMovieClips
# 15             20181212_412364_7RF  VisCodingTargetedMovieClips
# 16             20181214_412364_7RF  VisCodingTargetedMovieClips
# 17             20181216_412364_7RF  VisCodingTargetedMovieClips
# 18             20181218_412364_7RF  VisCodingTargetedMovieClips
# 19            20181219_412364_7_RF  VisCodingTargetedMovieClips
# 22             20190318_432375_7RF  VisCodingTargetedMovieClips
# 26             20190509_445270_7RF  VisCodingTargetedMovieClips
# 27             20181203_403491_7RF  VisCodingTargetedMovieClips
# 28             20181212_403491_7RF  VisCodingTargetedMovieClips
# 29             20190626_456917_7RF  VisCodingTargetedMovieClips
# 32             20190221_431246_7RF  VisCodingTargetedMovieClips
# 33             20190228_431246_7RF  VisCodingTargetedMovieClips
# 35  20190710_456916_7RF_Map_retake  VisCodingTargetedMovieClips
# 36             20190118_423606_7RF  VisCodingTargetedMovieClips
# 37             20190121_423606_7RF  VisCodingTargetedMovieClips
# 38             20190221_423606_7RF  VisCodingTargetedMovieClips
# 39             20190117_425493_7RF  VisCodingTargetedMovieClips
# 40    20190208_431023_VISp_175um_7  VisCodingTargetedMovieClips
# 41  20190128_431018_VISp_175um_7rf  VisCodingTargetedMovieClips
# 42             20190408_442709_7RF  VisCodingTargetedMovieClips
# 44             20194017_436662_7RF  VisCodingTargetedMovieClips
# 45  20190207_431018_VISp_175um_7rf  VisCodingTargetedMovieClips
# 46             20190410_440298_7RF  VisCodingTargetedMovieClips
# 48             20190409_435838_7RF  VisCodingTargetedMovieClips
# 49             20190313_431252_7RF  VisCodingTargetedMovieClips
# 50             20190314_433245_7RF  VisCodingTargetedMovieClips
# 52      20190625_453913_7RFmapping  VisCodingTargetedMovieClips
# 53             20181216_412366_7RF  VisCodingTargetedMovieClips
# 56       20190115_421136_7imagesRF  VisCodingTargetedMovieClips
# 57             20190117_425496_7RF  VisCodingTargetedMovieClips
# 58  20181206_416369_2P3_VISp_375_7  VisCodingTargetedMovieClips
# 59             20190419_445002_7RF  VisCodingTargetedMovieClips
# 60          20190715_461946_7RFmap              full_field_test
#
#    pkl_stage_name              lims_stage_name  \
# 2             NaN              full_field_test
# 3             NaN  VisCodingTargetedMovieClips
# 4             NaN  VisCodingTargetedMovieClips
# 5             NaN  VisCodingTargetedMovieClips
# 6             NaN  VisCodingTargetedMovieClips
# 9             NaN  VisCodingTargetedMovieClips
# 11            NaN              full_field_test
# 12            NaN  VisCodingTargetedMovieClips
# 13            NaN  VisCodingTargetedMovieClips
# 14            NaN  VisCodingTargetedMovieClips
# 15            NaN  VisCodingTargetedMovieClips
# 16            NaN  VisCodingTargetedMovieClips
# 17            NaN  VisCodingTargetedMovieClips
# 18            NaN  VisCodingTargetedMovieClips
# 19            NaN  VisCodingTargetedMovieClips
# 22            NaN  VisCodingTargetedMovieClips
# 26            NaN  VisCodingTargetedMovieClips
# 27            NaN  VisCodingTargetedMovieClips
# 28            NaN  VisCodingTargetedMovieClips
# 29            NaN  VisCodingTargetedMovieClips
# 32            NaN  VisCodingTargetedMovieClips
# 33            NaN  VisCodingTargetedMovieClips
# 35            NaN  VisCodingTargetedMovieClips
# 36            NaN  VisCodingTargetedMovieClips
# 37            NaN  VisCodingTargetedMovieClips
# 38            NaN  VisCodingTargetedMovieClips
# 39            NaN  VisCodingTargetedMovieClips
# 40            NaN  VisCodingTargetedMovieClips
# 41            NaN  VisCodingTargetedMovieClips
# 42            NaN  VisCodingTargetedMovieClips
# 44            NaN  VisCodingTargetedMovieClips
# 45            NaN  VisCodingTargetedMovieClips
# 46            NaN  VisCodingTargetedMovieClips
# 48            NaN  VisCodingTargetedMovieClips
# 49            NaN  VisCodingTargetedMovieClips
# 50            NaN  VisCodingTargetedMovieClips
# 52            NaN  VisCodingTargetedMovieClips
# 53            NaN  VisCodingTargetedMovieClips
# 56            NaN  VisCodingTargetedMovieClips
# 57            NaN  VisCodingTargetedMovieClips
# 58            NaN  VisCodingTargetedMovieClips
# 59            NaN  VisCodingTargetedMovieClips
# 60            NaN              full_field_test
#
#                       problem_type          desired_LIMS_stage_name
# 2   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 3   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 4   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 5   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 6   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 9   rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 11  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 12  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 13  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 14  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 15  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 16  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 17  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 18  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 19  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 22  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 26  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 27  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 28  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 29  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 32  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 33  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 35  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 36  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 37  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 38  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 39  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 40  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 41  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 42  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 44  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 45  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 46  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 48  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 49  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 50  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 52  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 53  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 56  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 57  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 58  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 59  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping
# 60  rf_mapping_incorrect_lims_name  OPHYS_7_receptive_field_mapping

# %%
experiments_with_naming_issues.query("problem_type == 'rf_mapping_missing_lims_name'")[cols_to_show]
# Out:
#     ophys_experiment_id  ophys_session_id  container_id          project_code  \
# 0             868245889         867455174     898954413        VisualBehavior
# 1             872434950         871522846     898954413        VisualBehavior
# 7             894725344         894247390     902748564        VisualBehavior
# 8             897374358         896264501     902748564        VisualBehavior
# 20            910199584         909228684     895259658  VisualBehaviorTask1B
# 23            853965797         853744857     845588020        VisualBehavior
# 24            862016695         861710170     845588020        VisualBehavior
# 25            864936381         864811045     845588020        VisualBehavior
# 30            914062473         913565955     904629174  VisualBehaviorTask1B
# 34            895418485         894835974     890047007        VisualBehavior
# 47            844394546         844073954     838105949        VisualBehavior
# 54            911644701         911457686     896318095  VisualBehaviorTask1B
# 55            912717370         912232900     896318095  VisualBehaviorTask1B
#
#    container_workflow_state experiment_workflow_state  \
# 0                    failed                    failed
# 1                    failed                    failed
# 7              container_qc                    failed
# 8              container_qc                    failed
# 20                   failed                    passed
# 23             container_qc                    failed
# 24             container_qc                    failed
# 25             container_qc                    failed
# 30                   failed                    passed
# 34             container_qc                    failed
# 47                   failed                    failed
# 54             container_qc                    failed
# 55             container_qc                    failed
#
#                    session_name session_type pkl_stage_name lims_stage_name  \
# 0           20190514_448897_7RF          NaN            NaN             NaN
# 1       20190520_448897_7RF_Map          NaN            NaN             NaN
# 7           20190625_456564_7RF          NaN            NaN             NaN
# 8           20190628_456564_7RF          NaN            NaN             NaN
# 20      20190719_460746_7RF_map          NaN            NaN             NaN
# 23          20190417_445270_7RF          NaN            NaN             NaN
# 24          20190502_445270_7RF          NaN            NaN             NaN
# 25          20190508_445270_7RF          NaN            NaN             NaN
# 30  20190729_462887_7RF_passive          NaN            NaN             NaN
# 34      20190626_456916_7RF_Map          NaN            NaN             NaN
# 47          20190401_435838_7RF          NaN            NaN             NaN
# 54          20190724_462468_7RF          NaN            NaN             NaN
# 55          20190725_462468_7RF          NaN            NaN             NaN
#
#                     problem_type          desired_LIMS_stage_name
# 0   rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 1   rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 7   rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 8   rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 20  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 23  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 24  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 25  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 30  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 34  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 47  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 54  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping
# 55  rf_mapping_missing_lims_name  OPHYS_7_receptive_field_mapping

# %%
experiments_with_naming_issues.query("problem_type == 'pkl_mismatch'")[cols_to_show]
# Out:
#     ophys_experiment_id  ophys_session_id  container_id          project_code  \
# 10            800034837         798782540     800219216        VisualBehavior
# 21            972666750         972022565     966316564  VisualBehaviorTask1B
# 31            901557228         898849158     890047007        VisualBehavior
# 43           1005123562        1004988945    1000740435  VisualBehaviorTask1B
# 51            974948847         974659900     968890932        VisualBehavior
#
#    container_workflow_state experiment_workflow_state  \
# 10                   failed                    failed
# 21                   failed                   created
# 31             container_qc                        qc
# 43                   failed                        qc
# 51                   failed                    failed
#
#                       session_name      session_type  \
# 10      20181219_408224_6_images_B  OPHYS_6_images_B
# 21       20191023_479835_session1b               NaN
# 31  20190702_456916_7RF_MAP_retake               NaN
# 43        486738_20200204_4imagesA  OPHYS_3_images_B
# 51        20191031_483803_3imagesA  OPHYS_1_images_A
#
#               pkl_stage_name   lims_stage_name  problem_type  \
# 10  OPHYS_2_images_A_passive  OPHYS_6_images_B  pkl_mismatch
# 21          OPHYS_1_images_B               NaN  pkl_mismatch
# 31          OPHYS_3_images_E               NaN  pkl_mismatch
# 43          OPHYS_4_images_A  OPHYS_3_images_B  pkl_mismatch
# 51          OPHYS_3_images_A  OPHYS_1_images_A  pkl_mismatch
#
#      desired_LIMS_stage_name
# 10  OPHYS_2_images_A_passive
# 21          OPHYS_1_images_B
# 31          OPHYS_3_images_E
# 43          OPHYS_4_images_A
# 51          OPHYS_3_images_A
