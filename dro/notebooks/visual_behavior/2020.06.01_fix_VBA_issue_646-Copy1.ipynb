# %%
from visual_behavior.ophys.response_analysis.response_analysis import ResponseAnalysis
import visual_behavior.data_access.loading as loading
import visual_behavior.visualization.ophys.summary_figures as sf

experiments_table = loading.get_filtered_ophys_experiment_table()
experiment_ids = experiments_table.query('model_outputs_available == True').index.values

experiment_id = 945586427
cell_specimen_id = 1022734194
dataset = loading.get_ophys_dataset(experiment_id)
# Out:
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/behavior_ophys_api/behavior_ophys_nwb_api.py:9: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
analysis = ResponseAnalysis(
    dataset, 
    overwrite_analysis_files=True, 
    use_extended_stimulus_presentations=True, 
    dataframe_format = 'tidy'
)
# Out:
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning:
#
# The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning:
#
# The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#
# WARNING:root:Could not find valid lines for the following data sources
# WARNING:root:acquiring (valid line label(s) = ['2p_acquiring']
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times

# %%
sf.make_cell_response_summary_plot(analysis, cell_specimen_id, split_by='lick_on_previous_flash')
# Out:
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# /home/dougo/.conda/envs/visual_behavior/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# saving stimulus_response_df
# /home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/running_processing.py:43: UserWarning:
#
# time array is 1 value shorter than encoder array. Last encoder value removed
#
#
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ...

# %%
sf.make_cell_response_summary_plot(analysis, cell_specimen_id, split_by='lick_on_next_flash')
# Out:
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ERROR:visual_behavior.ophys.sync.process_sync:Sync photodiode error needs to be fixed. Using assumed monitor delay: 0.0351
# resampling mesoscope 2P frame times
# ...

# %%
analysis.stimulus_response_df
# Out:
#          eventlocked_timestamps  cell_specimen_id  stimulus_presentations_id  \
# 0                     -0.466162        1022734183                          0
# 1                     -0.466162        1022734429                          0
# 2                     -0.466162        1022734432                          0
# 3                     -0.466162        1022734129                          0
# 4                     -0.466162        1022734137                          0
# ...                         ...               ...                        ...
# 1747923                0.652627        1022734224                       4801
# 1747924                0.652627        1022734228                       4801
# 1747925                0.652627        1022734464                       4801
# 1747926                0.652627        1022734152                       4801
# 1747927                0.652627        1022734133                       4801
#
# ...

# %%
analysis.trials_response_df.query('licked == True')
# Out:
#          eventlocked_timestamps  cell_specimen_id  trials_id  \
# 0                     -4.941318        1022734183          1
# 1                     -4.941318        1022734429          1
# 2                     -4.941318        1022734432          1
# 3                     -4.941318        1022734129          1
# 4                     -4.941318        1022734137          1
# ...                         ...               ...        ...
# 1093535                4.941318        1022734224        481
# 1093536                4.941318        1022734228        481
# 1093537                4.941318        1022734464        481
# 1093538                4.941318        1022734152        481
# 1093539                4.941318        1022734133        481
#
#          eventlocked_traces  mean_response  mean_baseline  p_value_omission  \
# 0                  0.319667       0.084105      -0.043581            0.1288
# 1                  0.417864       0.142475       0.009183            0.0813
# ...
