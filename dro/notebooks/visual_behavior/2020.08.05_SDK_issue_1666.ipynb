# %%
# on branch https://github.com/AllenInstitute/AllenSDK/tree/GH-1666/feature/get_visual_stimuli_df_gratings
from allensdk.brain_observatory.behavior.behavior_data_session import BehaviorDataSession
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

behavior_session_ids = [983472077, 818539440, 817861574]

session = {}
for bsid in behavior_session_ids:
    session[bsid] = BehaviorDataSession.from_lims(bsid)

session[behavior_session_ids[0]].stimulus_presentations.sample(10)
# Out:
# <style>.container { width:100% !important; }</style>
#                            duration  end_frame  image_index      image_name  \
# stimulus_presentations_id
# 2648                       0.250226   120400.0            0    gratings_0.0
# 1059                       0.250210    48877.0            3  gratings_270.0
# 1647                       0.250219    75346.0            0    gratings_0.0
# 3528                       0.250281   160013.0            0    gratings_0.0
# 856                        0.250207    39741.0            0    gratings_0.0
# 621                        0.233531    29160.0            1   gratings_90.0
# 582                        0.250219    27405.0            1   gratings_90.0
# 4456                       0.250222   201778.0            3  gratings_270.0
# 1798                       0.233527    82141.0            0    gratings_0.0
# 1953                       0.233520    89116.0            3  gratings_270.0
#
# ...

# %%
session[behavior_session_ids[0]].get_stimulus_metadata
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-57e779912d3e> in <module>
# ----> 1 session[behavior_session_ids[0]].get_stimulus_metadata
#
# AttributeError: 'BehaviorDataSession' object has no attribute 'get_stimulus_metadata'

# %%
session[behavior_session_ids[1]].stimulus_presentations.sample(10)
# Out:
#                            duration  end_frame  image_index image_name  \
# stimulus_presentations_id
# 1823                       0.250218    83396.0            4      im063
# 3773                       0.266879   171317.0            6      im085
# 662                        0.250202    31042.0            3      im061
# 2985                       0.250223   135790.0            4      im063
# 2000                       0.250176    91380.0            6      im085
# 1224                       0.250216    56383.0            2      im066
# 1348                       0.250209    61978.0            0      im065
# 2030                       0.250156    92733.0            4      im063
# 4746                       0.250201   215183.0            4      im063
# 1447                       0.250199    66444.0            0      im065
#
#                                                                    image_set  \
# stimulus_presentations_id
# ...

# %%
session[behavior_session_ids[2]].stimulus_presentations.sample(10)
# Out:
#                            duration  end_frame  image_index image_name  \
# stimulus_presentations_id
# 994                        0.250251    62732.0            1      im106
# 2231                       0.250204   118398.0            6      im031
# 1900                       0.250256   103502.0            4      im045
# 4751                       0.250186   231800.0            4      im045
# 4782                       0.250205   233195.0            1      im106
# 3111                       0.250169   157999.0            5      im054
# 4201                       0.250224   207048.0            4      im045
# 1443                       0.250226    82937.0            7      im035
# 3570                       0.250205   178654.0            3      im073
# 3672                       0.250206   183244.0            2      im075
#
#                                                                    image_set  \
# stimulus_presentations_id
# ...
