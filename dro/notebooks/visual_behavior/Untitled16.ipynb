# %%
from visual_behavior import database as db

# %%
summary = db.get_behavior_session_summary()

# %%
summary.sample(10)
# Out:
#                             _id mouse_id  \
# 4078   5d5eb469039a793a9a67398b   459521
# 10864  5d7fc902a0d593839cc09475   479169
# 8930   5d63f85bf5f7d572d87605b6   428442
# 6665   5d63edd9f5f7d572d87482ca   451787
# 6486   5d5f03beb448e9571146404f   456564
# 12172  5db736129693aa350f6d44d8   473189
# 7366   5d63f11cef7008c7b57502a5   453988
# 15271  5e50636025d2e05616de0990   489065
# 8740   5d63f77e03aacdf5ab75e6b3   423606
# 4663   5d5ec742131d3309e802e4c7   448060
#
#                       behavior_session_uuid           startdatetime  \
# 4078   813e2457-0af5-4df7-af3a-2842ad4fe11e 2019-06-18 20:13:37.815
# 10864  b735654d-239d-4d54-bc1b-7294db2e7dbb 2019-09-16 16:17:34.399
# 8930   17809ec6-91d0-4ed8-8d77-2283d7768d05 2019-02-18 16:41:05.038
# 6665   130f97a2-1c99-49a4-832b-13cad181b939 2019-05-13 20:31:21.038
# 6486   12ee36df-9e69-4843-bc5c-850985450a9e 2019-05-23 19:12:15.136
# 12172  67c6b80d-9566-4c6c-bf4f-d75b87ad363b 2019-10-28 17:03:49.654
# ...

# %%
len(summary)
# Out:
# 15405
