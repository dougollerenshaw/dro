# %%
from visual_behavior.data_access import loading

# %%
session_table = loading.get_filtered_ophys_session_table()
# Out:
# Getting all ophys sessions. This might take a while.

# %%
session_table
# Out:
#                   behavior_session_id  \
# ophys_session_id
# 860331718                   860533862
# 863981645                   864068649
# 842583486                   842729895
# 792619807                   792680306
# 794918442                   794968300
# ...                               ...
# 966314334                   966488947
# 1009837124                 1009868108
# 1010346697                 1010371498
# 1010607747                 1010669338
# 993228542                   993241575
#
#                                                 ophys_experiment_id  \
# ophys_session_id
# 860331718                                               [862848066]
# 863981645                                               [864370674]
# 842583486                                               [842973730]
# 792619807                                               [792815735]
# 794918442                                               [795073741]
# ...

# %%
from visual_behavior.visualization.qc.dash_app import functions
functions.load_container_qc_definitions()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-49158c5de47c> in <module>
#       1 from visual_behavior.visualization.qc.dash_app import functions
# ----> 2 functions.load_container_qc_definitions()
#
# ~/vb_qc_app/visual_behavior_analysis/visual_behavior/visualization/qc/dash_app/functions.py in load_container_qc_definitions()
#      40 def load_container_qc_definitions():
#      41     container_qc_definition_path = "/allen/programs/braintv/workgroups/nc-ophys/visual_behavior/qc_plots/container_plots/qc_definitions.json"
# ---> 42     return json.load(open(container_qc_definition_path))
#      43
#      44
#
# ~/.conda/envs/vb_qc_app/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294         cls=cls, object_hook=object_hook,
# ...

# %%
from importlib import reload
reload(functions)
meso_table = functions.refactor_sessions_table_mesoscope_for_qc()
# Out:
# /home/dougo/vb_qc_app/visual_behavior_analysis/visual_behavior/visualization/qc/dash_app/functions.py:349: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
meso_table
# Out:
#            age_in_days at_least_one_experiment_passed  behavior_session_id  \
# 952430817        209.0                           True          952554548.0
# 954954402        210.0                           True          953982960.0
# 955775716        212.0                           True          956010809.0
# 957020350        213.0                           True          957032492.0
# 958105827        216.0                           True          958234742.0
# ...                ...                            ...                  ...
# 911719666        167.0                           True          911904717.0
# 914161594        172.0                           True          914211263.0
# 914639324        173.0                           True          914705301.0
# 915306390        174.0                           True          915418411.0
# 929255311        195.0                           True          929341697.0
#
# ...
