# %%
import visual_behavior.database as db
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

import visual_behavior.data_access.loading as loading
import visual_behavior.validation.sdk as sdk_validation

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## get experiment table

# %%
experiment_table = loading.get_filtered_ophys_experiment_table()

# %% [markdown]
# ## get behavior session table with SDK failures appended

# %%
behavior_session_table = sdk_validation.get_behavior_session_table()
behavior_session_table.sample(10)
# Out:
#                      ophys_session_id  behavior_training_id equipment_name  \
# behavior_session_id
# 883857874                         NaN                   NaN     BEH.B-Box1
# 1033160354                        NaN                   NaN     BEH.G-Box3
# 978080433                         NaN                   NaN     BEH.F-Box3
# 815511978                         NaN                   NaN          BEH.G
# 900227468                         NaN                   NaN         MESO.1
# 944698858                         NaN                   NaN     BEH.F-Box1
# 852974537                 852794141.0                   NaN         MESO.1
# 831905148                         NaN                   NaN        CAM2P.5
# 992387617                         NaN                   NaN     BEH.F-Box6
# 823922950                         NaN                   NaN          BEH.F
#
#                          date_of_acquisition    donor_id  \
# behavior_session_id
# 883857874            2019-06-10 12:35:45.608   840355560
# 1033160354           2020-06-29 13:36:37.516  1024915441
# 978080433            2019-11-07 08:41:52.372   940744044
# 815511978            2019-01-30 13:18:05.635   791756316
# 900227468            2019-07-05 09:41:36.089   843122488
# 944698858            2019-09-12 08:50:34.306   887127186
# 852974537            2019-04-17 09:21:22.445   813702144
# 831905148            2019-03-04 10:45:26.252   784057617
# 992387617            2019-12-05 08:49:31.127   958769021
# 823922950            2019-02-15 14:17:20.522   803258370
#
#                                                          full_genotype  \
# behavior_session_id
# 883857874                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 1033160354               Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 978080433                Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 815511978                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 900227468            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 944698858                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 852974537                Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 831905148            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
# 992387617                Vip-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt
# 823922950            Slc17a7-IRES2-Cre/wt;Camk2a-tTA/wt;Ai93(TITL-G...
#
#                                     reporter_line  \
# behavior_session_id
# 883857874            [Ai148(TIT2L-GC6f-ICL-tTA2)]
# 1033160354           [Ai148(TIT2L-GC6f-ICL-tTA2)]
# 978080433            [Ai148(TIT2L-GC6f-ICL-tTA2)]
# 815511978            [Ai148(TIT2L-GC6f-ICL-tTA2)]
# 900227468                    [Ai93(TITL-GCaMP6f)]
# 944698858            [Ai148(TIT2L-GC6f-ICL-tTA2)]
# 852974537            [Ai148(TIT2L-GC6f-ICL-tTA2)]
# 831905148                    [Ai93(TITL-GCaMP6f)]
# 992387617            [Ai148(TIT2L-GC6f-ICL-tTA2)]
# 823922950                    [Ai93(TITL-GCaMP6f)]
#
#                                          driver_line sex  age_in_days  \
# behavior_session_id
# 883857874                             [Vip-IRES-Cre]   M        122.0
# 1033160354                            [Sst-IRES-Cre]   M        103.0
# 978080433                             [Sst-IRES-Cre]   M        116.0
# 815511978                             [Vip-IRES-Cre]   M        110.0
# 900227468            [Slc17a7-IRES2-Cre, Camk2a-tTA]   F        134.0
# 944698858                             [Vip-IRES-Cre]   M        149.0
# 852974537                             [Sst-IRES-Cre]   M        127.0
# 831905148            [Slc17a7-IRES2-Cre, Camk2a-tTA]   F        137.0
# 992387617                             [Vip-IRES-Cre]   F        123.0
# 823922950            [Slc17a7-IRES2-Cre, Camk2a-tTA]   M         85.0
#
#                                               foraging_id  \
# behavior_session_id
# 883857874            7a1c6873-8999-491d-8e45-7d5da579fbbc
# 1033160354           be4b87cd-759e-48ef-81c6-5c89fd46f2d2
# 978080433            46782778-444c-410a-a89a-5e24e287dea8
# 815511978            bbe569c0-fc17-4b55-b1df-f07e8e8fa9b9
# 900227468            01a085af-9434-4007-addb-46b0cbccb9a8
# 944698858            4cdf0e9f-7786-4d65-9bd8-de1e8bcfca47
# 852974537            fe7e3b1e-8461-41b6-9d1a-46dafedc6cfc
# 831905148            54bb73b2-e883-4846-8fce-c8d4dced3910
# 992387617            bf9b28de-c52f-4876-9aef-4c653f642fcd
# 823922950            d976eee7-2f74-44ca-b0fb-4451dae22da9
#
#                                           session_type  donor_in_ophys  \
# behavior_session_id
# 883857874                 TRAINING_4_images_A_training            True
# 1033160354             TRAINING_3_images_A_10uL_reward            True
# 978080433                 TRAINING_4_images_B_training            True
# 815511978                  TRAINING_2_gratings_flashed            True
# 900227468                     OPHYS_2_images_A_passive            True
# 944698858                 TRAINING_4_images_B_training            True
# 852974537                             OPHYS_4_images_B            True
# 831905148                             OPHYS_3_images_A            True
# 992387617            TRAINING_5_images_G_handoff_ready            True
# 823922950              TRAINING_3_images_A_10uL_reward            True
#
#                      project_id                       project_code  \
# behavior_session_id
# 883857874             844767092           VisualBehaviorMultiscope
# 1033160354            767756009                     VisualBehavior
# 978080433             873094517               VisualBehaviorTask1B
# 815511978             767756009                     VisualBehavior
# 900227468             844767092           VisualBehaviorMultiscope
# 944698858             767756009                     VisualBehavior
# 852974537             589467762               MesoscopeDevelopment
# 831905148             767756009                     VisualBehavior
# 992387617             894204169  VisualBehaviorMultiscope4areasx2d
# 823922950             767756009                     VisualBehavior
#
#                      in_filtered_experiments  average_projection  \
# behavior_session_id
# 883857874                               True                 NaN
# 1033160354                              True                 NaN
# 978080433                               True                 NaN
# 815511978                               True                 NaN
# 900227468                               True                 NaN
# 944698858                               True                 NaN
# 852974537                               True                 1.0
# 831905148                               True                 NaN
# 992387617                               True                 NaN
# 823922950                               True                 NaN
#
#                      cell_specimen_table  corrected_fluorescence_traces  \
# behavior_session_id
# 883857874                            NaN                            NaN
# 1033160354                           NaN                            NaN
# 978080433                            NaN                            NaN
# 815511978                            NaN                            NaN
# 900227468                            NaN                            NaN
# 944698858                            NaN                            NaN
# 852974537                            1.0                            1.0
# 831905148                            NaN                            NaN
# 992387617                            NaN                            NaN
# 823922950                            NaN                            NaN
#
#                      dff_traces  eye_tracking  licks  max_projection  \
# behavior_session_id
# 883857874                   NaN           NaN    1.0             NaN
# 1033160354                  NaN           NaN    1.0             NaN
# 978080433                   NaN           NaN    1.0             NaN
# 815511978                   NaN           NaN    1.0             NaN
# 900227468                   NaN           NaN    1.0             NaN
# 944698858                   NaN           NaN    1.0             NaN
# 852974537                   1.0           1.0    1.0             1.0
# 831905148                   NaN           NaN    1.0             NaN
# 992387617                   NaN           NaN    1.0             NaN
# 823922950                   NaN           NaN    1.0             NaN
#
#                      metadata  motion_correction  ophys_timestamps  rewards  \
# behavior_session_id
# 883857874                 1.0                NaN               NaN      1.0
# 1033160354                1.0                NaN               NaN      1.0
# 978080433                 1.0                NaN               NaN      1.0
# 815511978                 1.0                NaN               NaN      1.0
# 900227468                 1.0                NaN               NaN      1.0
# 944698858                 1.0                NaN               NaN      1.0
# 852974537                 1.0                1.0               1.0      1.0
# 831905148                 1.0                NaN               NaN      1.0
# 992387617                 1.0                NaN               NaN      1.0
# 823922950                 1.0                NaN               NaN      1.0
#
#                      running_data_df  running_speed  segmentation_mask_image  \
# behavior_session_id
# 883857874                        1.0            1.0                      NaN
# 1033160354                       1.0            1.0                      NaN
# 978080433                        1.0            1.0                      NaN
# 815511978                        1.0            1.0                      NaN
# 900227468                        1.0            1.0                      NaN
# 944698858                        1.0            1.0                      NaN
# 852974537                        1.0            1.0                      1.0
# 831905148                        1.0            1.0                      NaN
# 992387617                        1.0            1.0                      NaN
# 823922950                        1.0            1.0                      NaN
#
#                      stimulus_presentations  stimulus_templates  \
# behavior_session_id
# 883857874                               1.0                 1.0
# 1033160354                              1.0                 1.0
# 978080433                               1.0                 1.0
# 815511978                               1.0                 1.0
# 900227468                               1.0                 1.0
# 944698858                               1.0                 1.0
# 852974537                               1.0                 1.0
# 831905148                               1.0                 1.0
# 992387617                               1.0                 1.0
# 823922950                               1.0                 1.0
#
#                      stimulus_timestamps  task_parameters  trials  is_ophys  \
# behavior_session_id
# 883857874                            1.0              1.0     1.0       0.0
# 1033160354                           1.0              1.0     1.0       0.0
# 978080433                            1.0              1.0     1.0       0.0
# 815511978                            1.0              1.0     1.0       0.0
# 900227468                            1.0              1.0     1.0       0.0
# 944698858                            1.0              1.0     1.0       0.0
# 852974537                            1.0              1.0     1.0       1.0
# 831905148                            1.0              1.0     1.0       0.0
# 992387617                            1.0              1.0     1.0       0.0
# 823922950                            1.0              1.0     1.0       0.0
#
#                                       timestamp
# behavior_session_id
# 883857874            2020-04-12 12:27:52.133303
# 1033160354           2020-11-03 17:13:33.696876
# 978080433            2020-04-10 00:34:25.252821
# 815511978            2020-11-20 15:05:58.464534
# 900227468            2020-05-05 16:53:36.729409
# 944698858            2020-04-12 13:31:37.622483
# 852974537            2020-06-03 11:11:31.252715
# 831905148            2020-04-10 06:52:27.690425
# 992387617            2020-11-20 14:48:07.460393
# 823922950            2020-04-10 05:53:10.199795

# %% [markdown]
# ## build error df

# %%
# %%time
error_df = sdk_validation.build_error_df(behavior_session_table)
# Out:
# CPU times: user 1.38 s, sys: 377 ms, total: 1.76 s
# Wall time: 8.64 s

# %%
error_df.head(15)
# Out:
#     index                   timestamp sdk_version python_version  \
# 0       1  2020-11-20 14:10:24.931741       2.3.2          3.7.9
# 1       2  2020-11-20 15:00:27.062181       2.3.2          3.7.9
# 2       4  2020-11-20 15:00:27.710620       2.3.2          3.7.9
# 3       3  2020-11-20 15:00:28.607991       2.3.2          3.7.9
# 4       2  2020-11-20 15:01:07.154136       2.3.2          3.7.9
# 5       2  2020-11-20 15:01:11.813505       2.3.2          3.7.9
# 6       2  2020-11-20 15:01:12.744135       2.3.2          3.7.9
# 7       2  2020-11-20 15:01:17.383659       2.3.2          3.7.9
# 8       2  2020-11-20 15:01:17.561386       2.3.2          3.7.9
# 9       2  2020-11-20 15:01:17.780498       2.3.2          3.7.9
# 10      2  2020-11-20 15:01:17.924034       2.3.2          3.7.9
# 11      2  2020-11-20 15:01:20.300513       2.3.2          3.7.9
# 12      2  2020-11-20 15:01:24.699231       2.3.2          3.7.9
# 13      4  2020-11-20 15:01:23.448474       2.3.2          3.7.9
# 14      4  2020-11-20 15:01:09.463867       2.3.2          3.7.9
#
#                                              platform  behavior_session_id  \
# 0   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1037743363
# 1   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1050651840
# 2   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...            806109931
# 3   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...            979414755
# 4   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 5   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 6   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 7   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 8   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 9   Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 10  Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 11  Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 12  Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...           1012667846
# 13  Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...            778166125
# 14  Linux-3.10.0-514.26.2.el7.x86_64-x86_64-with-c...            911035712
#
#           failed_attribute                                error_class  \
# 0             eye_tracking  <class 'allensdk.OneResultExpectedError'>
# 1             eye_tracking                     <class 'RuntimeError'>
# 2             eye_tracking                     <class 'RuntimeError'>
# 3             eye_tracking                     <class 'RuntimeError'>
# 4             eye_tracking                     <class 'RuntimeError'>
# 5                    licks                       <class 'ValueError'>
# 6                 metadata                     <class 'RuntimeError'>
# 7                  rewards                       <class 'ValueError'>
# 8          running_data_df                       <class 'ValueError'>
# 9            running_speed                       <class 'ValueError'>
# 10  stimulus_presentations                       <class 'ValueError'>
# 11     stimulus_timestamps                       <class 'ValueError'>
# 12                  trials                       <class 'ValueError'>
# 13            eye_tracking                     <class 'RuntimeError'>
# 14            eye_tracking                     <class 'RuntimeError'>
#
#                                             traceback
# 0   Traceback (most recent call last):\n  File "/h...
# 1   Traceback (most recent call last):\n  File "/h...
# 2   Traceback (most recent call last):\n  File "/h...
# 3   Traceback (most recent call last):\n  File "/h...
# 4   Traceback (most recent call last):\n  File "/h...
# 5   Traceback (most recent call last):\n  File "/h...
# 6   Traceback (most recent call last):\n  File "/h...
# 7   Traceback (most recent call last):\n  File "/h...
# 8   Traceback (most recent call last):\n  File "/h...
# 9   Traceback (most recent call last):\n  File "/h...
# 10  Traceback (most recent call last):\n  File "/h...
# 11  Traceback (most recent call last):\n  File "/h...
# 12  Traceback (most recent call last):\n  File "/h...
# 13  Traceback (most recent call last):\n  File "/h...
# 14  Traceback (most recent call last):\n  File "/h...

# %%
len(error_df)
# Out:
# 81

# %% [markdown]
# ## look at some specific examples

# %%
print(error_df.iloc[0]['traceback'])
# Out:
# Traceback (most recent call last):
#   File "/home/dougo/code/visual_behavior_analysis/visual_behavior/validation/sdk.py", line 167, in validate_attribute
#     getattr(session, attribute)
#   File "/home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/behavior_ophys_session.py", line 432, in eye_tracking
#     dilation_frames=self._eye_tracking_dilation_frames)
#   File "/home/dougo/Code/AllenSDK/allensdk/internal/api/behavior_ophys_api.py", line 359, in get_eye_tracking
#     filepath = Path(self.get_eye_tracking_filepath())
#   File "/home/dougo/Code/AllenSDK/allensdk/api/cache.py", line 75, in wrapper
#     result = f(*args, **kwargs)
#   File "/home/dougo/Code/AllenSDK/allensdk/internal/api/behavior_ophys_api.py", line 348, in get_eye_tracking_filepath
#     return safe_system_path(self.lims_db.fetchone(query, strict=True))
#   File "/home/dougo/Code/AllenSDK/allensdk/internal/api/__init__.py", line 48, in fetchone
#     raise OneResultExpectedError
# allensdk.OneResultExpectedError

# %%
print(error_df.iloc[5]['traceback'])
# Out:
# Traceback (most recent call last):
#   File "/home/dougo/code/visual_behavior_analysis/visual_behavior/validation/sdk.py", line 224, in validate_attribute
#     getattr(session, attribute)
#   File "/home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/behavior_ophys_session.py", line 299, in licks
#     self._licks = self.api.get_licks()
#   File "/home/dougo/Code/AllenSDK/allensdk/api/cache.py", line 75, in wrapper
#     result = f(*args, **kwargs)
#   File "/home/dougo/Code/AllenSDK/allensdk/internal/api/behavior_ophys_api.py", line 243, in get_licks
#     rebase_function = self.get_stimulus_rebase_function()
#   File "/home/dougo/Code/AllenSDK/allensdk/internal/api/behavior_ophys_api.py", line 331, in get_stimulus_rebase_function
#     stimulus_rebase_function = get_stimulus_rebase_function(data, stimulus_timestamps_no_monitor_delay)
#   File "/home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/sync/__init__.py", line 288, in get_stimulus_rebase_function
#     raise ValueError("Number of stimulus timestamps in pickle file are "
# ValueError: Number of stimulus timestamps in pickle file are not equal to timestamps in the sync file (pickle=270070, sync=270005).

# %%
print(error_df.iloc[12]['traceback'])
# Out:
# Traceback (most recent call last):
#   File "/home/dougo/code/visual_behavior_analysis/visual_behavior/validation/sdk.py", line 224, in validate_attribute
#     getattr(session, attribute)
#   File "/home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/behavior_ophys_session.py", line 339, in trials
#     self._trials = self.api.get_trials()
#   File "/home/dougo/Code/AllenSDK/allensdk/api/cache.py", line 75, in wrapper
#     result = f(*args, **kwargs)
#   File "/home/dougo/Code/AllenSDK/allensdk/internal/api/behavior_ophys_api.py", line 272, in get_trials
#     licks = self.get_licks()
#   File "/home/dougo/Code/AllenSDK/allensdk/api/cache.py", line 75, in wrapper
#     result = f(*args, **kwargs)
#   File "/home/dougo/Code/AllenSDK/allensdk/internal/api/behavior_ophys_api.py", line 243, in get_licks
#     rebase_function = self.get_stimulus_rebase_function()
#   File "/home/dougo/Code/AllenSDK/allensdk/internal/api/behavior_ophys_api.py", line 331, in get_stimulus_rebase_function
#     stimulus_rebase_function = get_stimulus_rebase_function(data, stimulus_timestamps_no_monitor_delay)
#   File "/home/dougo/Code/AllenSDK/allensdk/brain_observatory/behavior/sync/__init__.py", line 288, in get_stimulus_rebase_function
#     raise ValueError("Number of stimulus timestamps in pickle file are "
# ValueError: Number of stimulus timestamps in pickle file are not equal to timestamps in the sync file (pickle=270070, sync=270005).
