# %%
from allensdk.brain_observatory.behavior.behavior_project_cache import BehaviorProjectCache as bpc
import os
import pandas as pd

cache_dir = "//allen/programs/braintv/workgroups/nc-ophys/visual_behavior/2020_cache/production_cache_temp"
manifest_path = os.path.join(cache_dir, 'manifest.json')

cache = bpc.from_lims(manifest_path)

behavior_session_table = cache.get_behavior_session_table()
# Out:
# Getting behavior-only session data. This might take a while...

# %%
osid = 1046147323
behavior_session_table.query('ophys_session_id == {}'.format(osid))['session_type'].iloc[0]
# Out:
# nan

# %%
osid = 1053696498
behavior_session_table.query('ophys_session_id == {}'.format(osid))['session_type'].iloc[0]
# Out:
# 'OPHYS_2_images_A_passive'

# %%
behavior_session_table
# Out:
#                      ophys_session_id  behavior_training_id equipment_name  \
# behavior_session_id
# 870987812                         NaN                   NaN     BEH.D-Box1
# 872953842                         NaN                   NaN     BEH.D-Box1
# 873774125                         NaN                   NaN     BEH.D-Box1
# 874790261                         NaN                   NaN     BEH.D-Box1
# 875207834                         NaN                   NaN     BEH.D-Box1
# ...                               ...                   ...            ...
# 875356675                         NaN                   NaN           NP.3
# 866287114                         NaN                   NaN           NP.3
# 910992337                         NaN                   NaN           NP.3
# 812897988                         NaN                   NaN          BEH.B
# 900284787                         NaN                   NaN           NP.3
#
# ...

# %%
behavior_session_table[pd.isnull(behavior_session_table['session_type'])]
# Out:
#                      ophys_session_id  behavior_training_id equipment_name  \
# behavior_session_id
# 960518793                 960475921.0                   NaN         MESO.1
# 974306643                         NaN                   NaN     BEH.D-Box1
# 867606646                 867455174.0                   NaN        CAM2P.5
# 871728975                 871522846.0                   NaN        CAM2P.5
# 768893620                 759960896.0                   NaN        CAM2P.5
# ...                               ...                   ...            ...
# 1000013931                        NaN                   NaN     BEH.F-Box2
# 999240213                         NaN                   NaN     BEH.F-Box2
# 970105563                         NaN                   NaN           NP.0
# 970115182                         NaN                   NaN           NP.0
# 970132238                         NaN                   NaN           NP.0
#
# ...
