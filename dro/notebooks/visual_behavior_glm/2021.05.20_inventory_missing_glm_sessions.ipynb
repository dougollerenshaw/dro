# %%
import visual_behavior_glm.GLM_analysis_tools as gat
from visual_behavior.data_access import loading

# %%
# %load_ext autoreload
# %autoreload 2

# %%
glm_version = '14_events_L2_optimize_by_session'
inventory = gat.inventory_glm_version(glm_version)

# %%
inventory
# Out:
# {'missing_experiments': [825623170,
#   956820482,
#   904155140,
#   877018118,
#   885933191,
#   973927944,
#   896160394,
#   846487947,
#   950852107,
#   946476556,
#   949637002,
#   958681110,
#   974945686,
#   884221469,
#   902487200,
#   823392290,
#   910600099,
#   893830436,
#   845037476,
#   951932454,
#   847241639,
#   977132456,
#   903403819,
#   826585773,
#   909090479,
#   977937585,
#   885067826,
#   947724724,
#   873968820,
#   948514870,
#   842975542,
#   844395446,
#   880375092,
#   878358326,
#   882935355,
#   822024770,
#   877691075,
#   953452368,
#   911146705,
#   881881171,
#   879332693,
#   884218326,
#   974384470,
#   825120601,
#   888666715,
#   889777243,
#   955278565,
#   843520488,
#   895422187,
#   873963889,
#   822641265,
#   873963891,
#   873154932,
#   875045489,
#   869969393,
#   877696762,
#   972701564,
#   957655294],
#  'missing_rois': [1080820354,
#   1080820361,
#   1080820380,
#   1080820393,
#   1080820397,
# ...

# %%
experiment_table = loading.get_released_ophys_experiment_table(exclude_ai94=True).reset_index()
experiment_table.query('ophys_experiment_id in {}'.format(inventory['missing_experiments']))['reporter_line'].value_counts()
# Out:
# Ai148(TIT2L-GC6f-ICL-tTA2)    2
# Name: reporter_line, dtype: int64

# %%
results = gat.retrieve_results(
    search_dict = {'glm_version': glm_version},
)

# %%
results = results.reset_index()

# %%
inv = gat.get_experiment_inventory(results)
inv
# Out:
#                     equipment_name  \
# ophys_experiment_id
# 951980471                   MESO.1
# 951980484                   MESO.1
# 951980473                   MESO.1
# 951980479                   MESO.1
# 951980475                   MESO.1
# ...                            ...
# 962473308                  CAM2P.3
# 963394081                  CAM2P.3
# 964440177                  CAM2P.3
# 965228771                  CAM2P.3
# 965928394                  CAM2P.3
#
#                                                      full_genotype  mouse_id  \
# ophys_experiment_id
# 951980471            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980484            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980473            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980479            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980475            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# ...

# %%
inv.query('glm_version_14_events_L2_optimize_by_session_exists == False')
# Out:
#                     equipment_name  \
# ophys_experiment_id
# 873963891                   MESO.1
# 873963889                   MESO.1
#
#                                                      full_genotype  mouse_id  \
# ophys_experiment_id
# 873963891            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    448366
# 873963889            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    448366
#
#                                   reporter_line     driver_line sex  \
# ophys_experiment_id
# 873963891            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   M
# 873963889            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   M
#
#                      age_in_days      cre_line indicator  session_number  ...  \
# ophys_experiment_id                                                       ...
# 873963891                  127.0  Sst-IRES-Cre   GCaMP6f               5  ...
# 873963889                  127.0  Sst-IRES-Cre   GCaMP6f               5  ...
#
# ...

# %%
inv.query('glm_version_14_events_L2_optimize_by_session_exists == True')
# Out:
#                     equipment_name  \
# ophys_experiment_id
# 951980471                   MESO.1
# 951980484                   MESO.1
# 951980473                   MESO.1
# 951980479                   MESO.1
# 951980475                   MESO.1
# ...                            ...
# 962473308                  CAM2P.3
# 963394081                  CAM2P.3
# 964440177                  CAM2P.3
# 965228771                  CAM2P.3
# 965928394                  CAM2P.3
#
#                                                      full_genotype  mouse_id  \
# ophys_experiment_id
# 951980471            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980484            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980473            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980479            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980475            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# ...

# %%
from visual_behavior_glm.glm import GLM

# %%
oeid = 873963891
version = '14_events_L2_optimize_by_session'
glm = GLM(
    oeid, 
    version, 
    use_previous_fit=False,  # if True, uses cached fit if available (False by default)
    log_results=True, # if True, logs fit results to mongo database (True by default)
    log_weights=True, # if True, logs weights to mongo database (True by default)
    NO_DROPOUTS=False, # if True, does not perform dropout analysis (False by default)
    TESTING=False, # if True, fits only the first 6 cells in the experiment (False by default)
)
# Out:
# importing GLM_fit_tools from /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_14_events_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py
# Fitting ophys_experiment_id: 873963891
# Loading data
# Processing df/f data
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# ...

# %%
oeid = 873963889
version = '14_events_L2_optimize_by_session'
glm = GLM(
    oeid, 
    version, 
    use_previous_fit=False,  # if True, uses cached fit if available (False by default)
    log_results=True, # if True, logs fit results to mongo database (True by default)
    log_weights=True, # if True, logs weights to mongo database (True by default)
    NO_DROPOUTS=False, # if True, does not perform dropout analysis (False by default)
    TESTING=False, # if True, fits only the first 6 cells in the experiment (False by default)
)
# Out:
# importing GLM_fit_tools from /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_14_events_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py
# Fitting ophys_experiment_id: 873963889
# Loading data
# Processing df/f data
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# ...

# %%
oeid = 951980473
version = '14_events_L2_optimize_by_session'
glm = GLM(
    oeid, 
    version, 
    use_previous_fit=False,  # if True, uses cached fit if available (False by default)
    log_results=True, # if True, logs fit results to mongo database (True by default)
    log_weights=True, # if True, logs weights to mongo database (True by default)
    NO_DROPOUTS=False, # if True, does not perform dropout analysis (False by default)
    TESTING=False, # if True, fits only the first 6 cells in the experiment (False by default)
)
# Out:
# importing GLM_fit_tools from /allen/programs/braintv/workgroups/nc-ophys/visual_behavior/ophys_glm/v_14_events_L2_optimize_by_session/frozen_model_files/GLM_fit_tools.py
# Fitting ophys_experiment_id: 951980473
# Loading data
# Processing df/f data
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# /allen/programs/braintv/workgroups/nc-ophys/Doug/code/AllenSDK/allensdk/brain_observatory/sync_dataset.py:109: UserWarning: The loaded sync file contains the following deprecated line label keys: {'cam1_exposure', 'cam2_exposure'}. Consider updating the sync file line labels.
#   self._check_line_labels()
# WARNING:root:Could not find valid lines for the following data sources
# ...
